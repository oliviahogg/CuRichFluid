# %% [markdown]
# # Load Libraries

# %%
# %matplotlib inline
from matplotlib.cm import get_cmap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import PySulfSat as ss
import Thermobar as pt
import warnings

# %%
# check version of PySulfSat
print(ss.__version__)
# Out:
# 1.0.3

# %% [markdown]
# ## Modeling sulfide and sulfate saturation, using PySulfSat

# %%
empty_na = pd.read_excel('PetThermo_output.xlsx', index_col=0)

empty_na['pressure_bar'] = pd.to_numeric(empty_na['pressure_bar'], errors='coerce')
empty_na.dropna(subset=['pressure_bar'], inplace=True)
empty_index = pd.concat([empty_na], axis=0,ignore_index=True)

# %% [markdown]
# ### Choose an SCSS model

# %%
# calculating the SCSS: sulfide concentration at sulfide saturation (ppm)
# here we use O'Neill 2021:
ONeill_MeasSulf=ss.calculate_O2021_SCSS(df=empty_index, T_K=empty_index['T_C']+273.15, 
P_kbar=empty_index['pressure_bar']/1000,Fe_FeNiCu_Sulf=0.6,Fe3Fet_Liq=empty_index['Fe3Fet_Liq'])

ONeill_MeasSulf.head() # we use column 'SCSS2_ppm'
# Out:
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.
#      SCSS2_ppm       LnS  Ln_a_FeO  Ln_a_FeS    DeltaG  LnCS2_calc  index  \
# 0  1715.975128  7.447737 -2.449595 -0.572566  6.343029   -0.772321      0
# 1  1704.288771  7.440903 -2.441726 -0.572722  6.369009   -0.797110      1
# 2  1692.552849  7.433993 -2.433816 -0.572873  6.395152   -0.822102      2
# 3  1680.771689  7.427008 -2.426005 -0.573017  6.421460   -0.847439      3
# 4  1668.943385  7.419946 -2.418287 -0.573154  6.447934   -0.873122      4
#
#            T_C  P_bar             h  ...  CO2_Qtz  Fe3Fet_Qtz  h_Qtz  \
# 0  1419.800000  10000 -1.156980e+06  ...      NaN         NaN    NaN
# 1  1414.801613  10000 -1.158193e+06  ...      NaN         NaN    NaN
# 2  1409.803226  10000 -1.147238e+06  ...      NaN         NaN    NaN
# 3  1404.804839  10000 -1.136254e+06  ...      NaN         NaN    NaN
# 4  1399.806452  10000 -1.125508e+06  ...      NaN         NaN    NaN
#
#    mass_Qtz  v_Qtz  rho_Qtz  newentry       newcolumn  \
# 0       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 1       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 2       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 3       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 4       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
#
#                      unique  Fe_FeNiCu_Sulf_calc
# 0  P_10000.0_H2O_0.1_QFM1.2                  0.6
# 1  P_10000.0_H2O_0.1_QFM1.2                  0.6
# 2  P_10000.0_H2O_0.1_QFM1.2                  0.6
# 3  P_10000.0_H2O_0.1_QFM1.2                  0.6
# 4  P_10000.0_H2O_0.1_QFM1.2                  0.6
#
# [5 rows x 380 columns]

# %%
# Another method could be to use Li and Zhang 2022:
LiZhang22=ss.calculate_LiZhang2022_SCSS(df=empty_index, T_K=empty_index['T_C']+273.15, 
P_kbar=empty_index['pressure_bar']/1000,
                                        Fe_FeNiCu_Sulf=0.6,
                                        Fe3Fet_Liq=empty_index['Fe3Fet_Liq'], 
                                        H2O_Liq=empty_index['H2O_Liq'])
LiZhang22.head()
# Out:
# Using inputted Fe_FeNiCu_Sulf ratio for calculations.
# replacing Fe3Fet_Liq in the original dataframe with that input into the function
#       SCSS_Tot  index          T_C  P_bar             h           s  \
# 0  1199.032880      0  1419.800000  10000 -1.156980e+06  287.616343
# 1  1188.115149      1  1414.801613  10000 -1.158193e+06  286.903754
# 2  1177.172926      2  1409.803226  10000 -1.147238e+06  283.668676
# 3  1166.249641      3  1404.804839  10000 -1.136254e+06  280.444223
# 4  1155.343574      4  1399.806452  10000 -1.125508e+06  277.285566
#
#            v      dvdp    logfO2   SiO2_Liq  ...    Al_cat    Fe_cat  \
# 0  35.892378 -0.000149 -4.297773  48.914035  ...  0.138235  0.059781
# 1  35.838843 -0.000134 -4.338601  48.849762  ...  0.139357  0.059926
# 2  35.481494 -0.000133 -4.379672  48.784859  ...  0.140498  0.060067
# 3  35.125015 -0.000132 -4.420988  48.720622  ...  0.141634  0.060201
# 4  34.776054 -0.000131 -4.462551  48.657025  ...  0.142765  0.060329
#
#      Mn_cat    Mg_cat    Ca_cat    Na_cat     K_cat     P_cat  H_cat   Fe3_cat
# 0  0.001540  0.175258  0.109207  0.035081  0.011251  0.001539    0.0  0.016050
# 1  0.001556  0.172719  0.110172  0.035435  0.011367  0.001555    0.0  0.016155
# 2  0.001572  0.170147  0.111150  0.035795  0.011485  0.001571    0.0  0.016260
# 3  0.001588  0.167592  0.112121  0.036155  0.011603  0.001588    0.0  0.016366
# 4  0.001604  0.165055  0.113084  0.036515  0.011720  0.001604    0.0  0.016470
#
# [5 rows x 409 columns]

# %% [markdown]
# ### Choose SCAS model

# %%
# calculating the SCAS (ppm):
# here using the model of Zajacz and Tsay 2022:
ZT22_SCAS=ss.calculate_ZT2022_SCAS(df=empty_index, T_K=empty_index['T_C']+273.15)

ZT22_SCAS.head() # we use column 'SCAS6_ppm'
# Out:
#       SCAS6_ppm  index          T_C  P_bar             h           s  \
# 0  19901.972716      0  1419.800000  10000 -1.156980e+06  287.616343
# 1  19413.045842      1  1414.801613  10000 -1.158193e+06  286.903754
# 2  18938.279419      2  1409.803226  10000 -1.147238e+06  283.668676
# 3  18480.066957      3  1404.804839  10000 -1.136254e+06  280.444223
# 4  18037.530339      4  1399.806452  10000 -1.125508e+06  277.285566
#
#            v      dvdp    logfO2   SiO2_Liq  ...  H2O_Qtz  CO2_Qtz  \
# 0  35.892378 -0.000149 -4.297773  48.914035  ...      NaN      NaN
# 1  35.838843 -0.000134 -4.338601  48.849762  ...      NaN      NaN
# 2  35.481494 -0.000133 -4.379672  48.784859  ...      NaN      NaN
# 3  35.125015 -0.000132 -4.420988  48.720622  ...      NaN      NaN
# 4  34.776054 -0.000131 -4.462551  48.657025  ...      NaN      NaN
#
#    Fe3Fet_Qtz  h_Qtz  mass_Qtz  v_Qtz  rho_Qtz  newentry       newcolumn  \
# 0         NaN    NaN       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 1         NaN    NaN       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 2         NaN    NaN       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 3         NaN    NaN       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
# 4         NaN    NaN       NaN    NaN      NaN         1  H2O_0.1_QFM1.2
#
#                      unique
# 0  P_10000.0_H2O_0.1_QFM1.2
# 1  P_10000.0_H2O_0.1_QFM1.2
# 2  P_10000.0_H2O_0.1_QFM1.2
# 3  P_10000.0_H2O_0.1_QFM1.2
# 4  P_10000.0_H2O_0.1_QFM1.2
#
# [5 rows x 374 columns]

# %% [markdown]
# ### Choose a sulfur-speciation model
#
# #### we choose the model by Jugo et al., (2010) which relies on $\Delta$QFM calculated with respect to the buffer by Frost et al., (1991)

# %%
# Use Thermobar to calculate delta QFM relative to the Frost buffer

buffers=pt.convert_fo2_to_buffer(fo2=10**empty_index['logfO2'], T_K=empty_index['T_C']+273.15, 
                    P_kbar=empty_index['P_bar']/1000)
buffers.head()

empty_index['deltaQFM_Frost1991'] = buffers['DeltaQFM_Frost1991']

# calculate fraction of sulphate relative to total sulfur in the melt (s6+/Stot):
empty_index['jugo_s6st'] = 1 /(1+10**(2.1-2*empty_index['deltaQFM_Frost1991']))
empty_index['jugo_s6st']
# Out:
# 0       0.603861
# 1       0.605121
# 2       0.606387
# 3       0.607660
# 4       0.608938
#           ...
# 2440    0.801891
# 2441    0.803901
# 2442    0.805914
# 2443    0.807930
# 2444    0.809949
# Name: jugo_s6st, Length: 2445, dtype: float64

# %%
# alternative sulfur-speciaiton model by O'Neill and Mavrogenes, (2022)
# calculates s6+/Stot from log(fO2) rather than delta QFM

calcS_OM2022_Givenfo2=ss.calculate_OM2022_S6St(df=empty_index, 
                                               T_K=empty_index['T_C']+273.15,
                                               logfo2=empty_index['logfO2'])
calcS_OM2022_Givenfo2.head()
# Out:
#    S6St_Liq  LnCS2_calc  LnCS6_calc   LnKSO2S2    LnS6S2  deltaQFM_calc  \
# 0  0.989675   -0.775145   10.808895 -12.770788  4.562853       1.920195
# 1  0.989640   -0.799973   10.872678 -12.866708  4.559360       1.923190
# 2  0.989605   -0.825003   10.936954 -12.963203  4.556024       1.926204
# 3  0.989572   -0.850379   11.001559 -13.060278  4.552814       1.929235
# 4  0.989541   -0.876101   11.066496 -13.157940  4.549730       1.932284
#
#    index          T_C  P_bar             h  ...  Ca_Liq_cat_frac  \
# 0      0  1419.800000  10000 -1.156980e+06  ...         0.109207
# 1      1  1414.801613  10000 -1.158193e+06  ...         0.110172
# 2      2  1409.803226  10000 -1.147238e+06  ...         0.111150
# 3      3  1404.804839  10000 -1.136254e+06  ...         0.112121
# 4      4  1399.806452  10000 -1.125508e+06  ...         0.113084
#
#    Al_Liq_cat_frac  Na_Liq_cat_frac  K_Liq_cat_frac  Ti_Liq_cat_frac  \
# 0         0.138235         0.035081        0.011251         0.004719
# 1         0.139357         0.035435        0.011367         0.004764
# 2         0.140498         0.035795        0.011485         0.004810
# 3         0.141634         0.036155        0.011603         0.004856
# 4         0.142765         0.036515        0.011720         0.004902
#
#    P_Liq_cat_frac  Mg_Number_Liq_NoFe3  Mg_Number_Liq_Fe3  Fe2Fet_Liq_calc  \
# 0        0.001539             0.697985           0.745648         0.762286
# 1        0.001555             0.694203           0.742408         0.760529
# 2        0.001571             0.690315           0.739075         0.758739
# 3        0.001588             0.686398           0.735713         0.756946
# 4        0.001604             0.682450           0.732323         0.755150
#
#    Fe2_Liq_cat_frac
# 0          0.057805
# 1          0.057861
# 2          0.057913
# 3          0.057957
# 4          0.057995
#
# [5 rows x 405 columns]

# %% [markdown]
# ## Modelling Degassing of Cl and S

# %%
warnings.filterwarnings('ignore', category=pd.core.generic.SettingWithCopyWarning)

# create empty dataframe
syst_mass = pd.DataFrame()

for i in empty_index.unique.unique():
    
    dfuniq = empty_index[empty_index.unique == i]
    
    # mass of initial melt (g)
    dfuniq['i_M_melt'] = dfuniq['mass_Liq'].iloc[0]
    
    # Melt Fraction at step i
    dfuniq['melt_f'] = dfuniq['mass_Liq'].div(dfuniq['i_M_melt'])
    
    # Mass of cumulative fluid (inc first step)
    dfuniq['cum_mass_fluid']=dfuniq['mass_fluid1'].cumsum()
    
    # Mass of cumulative fluid (minus first step)
    dfuniq['cum_mass_fluid_notstep1']=dfuniq['cum_mass_fluid']-dfuniq['mass_fluid1'].iloc[0]
    
    #PW fluid exsolved each step
    dfuniq['M_fluid_PW_H2O']=(dfuniq['H2O_fluid1']/100)*(dfuniq['mass_fluid1'])
    # Cumulative across all steps
    dfuniq['fluid_cum_sum_H2O']=dfuniq['M_fluid_PW_H2O'].cumsum()
    dfuniq['fluid_cum_sum_H2O'].replace([np.inf, -np.inf], 0, inplace=True)
    dfuniq['fluid_cum_sum_H2O'].fillna(0, inplace=True)
    
    # mass of first/initial fluid (g)
    dfuniq['i_M_fluid'] = dfuniq['fluid_cum_sum_H2O'].iloc[0]
    
    # mass of solid crystals (g) at step i 
    dfuniq['M_solid'] = dfuniq['i_M_melt'] - dfuniq['mass_Liq']-dfuniq['fluid_cum_sum_H2O']
    
    # mass of solid crystals (g) at step i 
    dfuniq['i_M_solid'] = dfuniq['M_solid'].iloc[0]
    
    #append to dataframe
    syst_mass = pd.concat([syst_mass,dfuniq],ignore_index=True)

# %%
# Add SCSS, SCAS and S-speciation calculations to working dataframe:

syst_mass['DeltaQFM_OMbuff'] = calcS_OM2022_Givenfo2['deltaQFM_calc'].values
syst_mass['DeltaQFM_JUGO'] = buffers['DeltaQFM_Frost1991']
syst_mass['DeltaQFM_frostbuff'] = buffers['DeltaQFM_Frost1991'].values

syst_mass['SCSS_liz'] = LiZhang22['SCSS_Tot'].values

syst_mass['SCSS_OM21'] = ONeill_MeasSulf['SCSS2_ppm'].values
syst_mass['SCAS']=ZT22_SCAS['SCAS6_ppm'].values

syst_mass['S6St_OMfO2'] = calcS_OM2022_Givenfo2['S6St_Liq'].values
syst_mass['jugo_s6st'] = empty_index['jugo_s6st']

# %%
syst_mass[['jugo_s6st','S6St_OMfO2','SCAS','SCSS_OM21','DeltaQFM_frostbuff']].head()
# Out:
#    jugo_s6st  S6St_OMfO2          SCAS    SCSS_OM21  DeltaQFM_frostbuff
# 0   0.603861    0.989675  19901.972716  1715.975128            1.141544
# 1   0.605121    0.989640  19413.045842  1704.288771            1.142689
# 2   0.606387    0.989605  18938.279419  1692.552849            1.143840
# 3   0.607660    0.989572  18480.066957  1680.771689            1.144999
# 4   0.608938    0.989541  18037.530339  1668.943385            1.146164

# %% [markdown]
# ### Setting S fluid-melt partition coefficients

# %%
DS = np.empty(len(syst_mass), dtype=float) 
DS.dtype
# Out:
# dtype('float64')

# %%
syst_mass['pressure_bar_str'] = syst_mass.pressure_bar.astype(str)
syst_mass['pressure_bar_str']
# Out:
# 0       10000
# 1       10000
# 2       10000
# 3       10000
# 4       10000
#         ...
# 2440      500
# 2441      500
# 2442      500
# 2443      500
# 2444      500
# Name: pressure_bar_str, Length: 2445, dtype: object

# %%
# We model DS_fluid-melt using estimates from Keppler (2010) and Masotta et al., (2016) 
# for an oxidised melt.
# DS_fluid-melt ranges from 1 to 200 between SiO2 contents of 45 to 80 wt%

DS_10000 =  {45:1, 50:1, 55:2, 60:5, 65:10, 70:15, 75:40, 80:70} 

DS_8000 =  {45:1, 50:1, 55:2, 60:5, 65:10, 70:15, 75:40, 80:70} 

DS_4000 =  {45:1, 50:1, 55:2, 60:5, 65:10, 70:15, 75:40, 80:70}

DS_2000 =  {45:1, 50:1, 55:2, 60:5, 65:10, 70:15, 75:40, 80:70}

DS_1000 =  {45:1, 50:1, 55:3, 60:8, 65:15, 70:30, 75:60, 80:90}

DS_500 =  {45:10, 50:10, 55:20, 60:30, 65:50, 70:70, 75:100, 80:200}

DS_dict = {'10000':DS_10000,'8000':DS_8000,'4000':DS_4000,'2000':DS_2000,'1000':DS_1000, '500':DS_500}

# %%
# Plot and print the equation for lines connecting points
for name, data in DS_dict.items():
    x = list(data.keys())
    y = list(data.values())


    # Plot the data points
    plt.scatter(x, y, label=name,  s=80)

    # Calculate the equations of the lines connecting points
    equations = []
    for i in range(len(x) - 1):
        x1, y1 = x[i], y[i]
        x2, y2 = x[i + 1], y[i + 1]
        slope = (y2 - y1) / (x2 - x1)
        intercept = y1 - slope * x1
        equations.append(f"{slope:.2f}x + {intercept:.2f} for {x1} <= x <= {x2}")
    
    # Print the equations of the lines
    for eq in equations:
        print(f"{name}: {eq}")

    # Plot the lines connecting points
    for i in range(len(x) - 1):
        plt.plot([x[i], x[i + 1]], [y[i], y[i + 1]], linestyle='-', color='blue')

# Add labels and legend
plt.xlabel('sio2')
plt.ylabel('DS')
plt.legend()
plt.show()

# Sample DataFrame 'systmass' with 'SiO2_Liq' and 'pressure_bar_str' columns
# Replace this with your actual DataFrame
syst_mass[['SiO2_Liq', 'pressure_bar_str']]

# Create a list to store calculated values
calculated_values = []

# Function to calculate DS_calc for each row
def calculate_DS_calc(row):
    SiO2_Liq = row['SiO2_Liq']
    pressure_bar_str = row['pressure_bar_str']

    # Check if pressure_bar_str exists in DS_dict
    if pressure_bar_str in DS_dict:
        equations = DS_dict[pressure_bar_str]

        # Extract x values from the equation
        x_values = list(equations.keys())

        # Find the closest lower and upper x values in the equation
        closest_lower_x = max([x for x in x_values if x <= SiO2_Liq], default=None)
        closest_upper_x = min([x for x in x_values if x >= SiO2_Liq], default=None)

        if closest_lower_x is not None and closest_upper_x is not None:
            slope = (equations[closest_upper_x] - equations[closest_lower_x]) / (closest_upper_x - closest_lower_x)
            intercept = equations[closest_lower_x] - slope * closest_lower_x
            DS_calc = slope * SiO2_Liq + intercept
            return DS_calc

    return None



# Calculate DS_calc for each row and store it in the list
for index, row in syst_mass.iterrows():
    calculated_value = calculate_DS_calc(row)
    calculated_values.append(calculated_value)

# Add the calculated values to the DataFrame
syst_mass['DS_calc'] = calculated_values

# Print the updated DataFrame with DS_calc values
print(syst_mass[['pressure_bar_str','DS_calc', 'SiO2_Liq']])


# Assuming syst_mass is your DataFrame with SiO2_Liq and DS_calc columns
# Replace with your actual DataFrame name if different
x = syst_mass['SiO2_Liq']
y = syst_mass['DS_calc']

plt.scatter(x, y, label='DS_calc', color='blue')
plt.xlabel('SiO2_Liq')
plt.ylabel('DS_calc')
plt.title('SiO2_Liq vs. DS_calc')
plt.legend()
plt.grid(True)
plt.show()


# Plot the scatter points
plt.scatter(x, y, label='DS_calc', color='blue')

# Overlay the original equations as lines
for name, data in DS_dict.items():
    x_values = list(data.keys())
    y_values = list(data.values())
    plt.plot(x_values, y_values, label=f'Original {name} Equation', linestyle='--')

plt.xlabel('SiO2_Liq')
plt.ylabel('DS_calc')
plt.title('SiO2_Liq vs. DS_calc')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 10000: 0.00x + 1.00 for 45 <= x <= 50
# 10000: 0.20x + -9.00 for 50 <= x <= 55
# 10000: 0.60x + -31.00 for 55 <= x <= 60
# 10000: 1.00x + -55.00 for 60 <= x <= 65
# 10000: 1.00x + -55.00 for 65 <= x <= 70
# 10000: 5.00x + -335.00 for 70 <= x <= 75
# 10000: 6.00x + -410.00 for 75 <= x <= 80
# 8000: 0.00x + 1.00 for 45 <= x <= 50
# 8000: 0.20x + -9.00 for 50 <= x <= 55
# 8000: 0.60x + -31.00 for 55 <= x <= 60
# 8000: 1.00x + -55.00 for 60 <= x <= 65
# 8000: 1.00x + -55.00 for 65 <= x <= 70
# 8000: 5.00x + -335.00 for 70 <= x <= 75
# 8000: 6.00x + -410.00 for 75 <= x <= 80
# 4000: 0.00x + 1.00 for 45 <= x <= 50
# 4000: 0.20x + -9.00 for 50 <= x <= 55
# 4000: 0.60x + -31.00 for 55 <= x <= 60
# 4000: 1.00x + -55.00 for 60 <= x <= 65
# 4000: 1.00x + -55.00 for 65 <= x <= 70
# 4000: 5.00x + -335.00 for 70 <= x <= 75
# 4000: 6.00x + -410.00 for 75 <= x <= 80
# 2000: 0.00x + 1.00 for 45 <= x <= 50
# 2000: 0.20x + -9.00 for 50 <= x <= 55
# 2000: 0.60x + -31.00 for 55 <= x <= 60
# 2000: 1.00x + -55.00 for 60 <= x <= 65
# 2000: 1.00x + -55.00 for 65 <= x <= 70
# 2000: 5.00x + -335.00 for 70 <= x <= 75
# 2000: 6.00x + -410.00 for 75 <= x <= 80
# 1000: 0.00x + 1.00 for 45 <= x <= 50
# 1000: 0.40x + -19.00 for 50 <= x <= 55
# 1000: 1.00x + -52.00 for 55 <= x <= 60
# 1000: 1.40x + -76.00 for 60 <= x <= 65
# 1000: 3.00x + -180.00 for 65 <= x <= 70
# 1000: 6.00x + -390.00 for 70 <= x <= 75
# 1000: 6.00x + -390.00 for 75 <= x <= 80
# 500: 0.00x + 10.00 for 45 <= x <= 50
# 500: 2.00x + -90.00 for 50 <= x <= 55
# 500: 2.00x + -90.00 for 55 <= x <= 60
# 500: 4.00x + -210.00 for 60 <= x <= 65
# 500: 4.00x + -210.00 for 65 <= x <= 70
# 500: 6.00x + -350.00 for 70 <= x <= 75
# 500: 20.00x + -1400.00 for 75 <= x <= 80
#      pressure_bar_str    DS_calc   SiO2_Liq
# 0               10000   1.000000  48.914035
# 1               10000   1.000000  48.849762
# 2               10000   1.000000  48.784859
# 3               10000   1.000000  48.720622
# 4               10000   1.000000  48.657025
# ...               ...        ...        ...
# 2440              500  79.371715  71.561953
# 2441              500  81.407842  71.901307
# 2442              500  83.374402  72.229067
# 2443              500  85.272837  72.545473
# 2444              500  87.104982  72.850830
#
# [2445 rows x 3 columns]

# %%
# Append S fluid-melt partition coeffcients to the master dataframe
syst_mass['DS_fm'] = syst_mass['DS_calc']

# %% [markdown]
# ### Setting Cl fluid-melt partition coefficients

# %%
DCl = np.empty(len(syst_mass), dtype=float)

# %%
# We model DCl_fluid-melt using estimates from Tattitch et al., (2021) 
# DCl_fluid-melt ranges from 3 to 65 between SiO2 contents of 45 to 80 wt%

DCl_10000 =  {45:3, 50:4, 55:5, 60:8, 65:15, 70:25, 75:40, 80:65}

DCl_8000 =  {45:3, 50:4, 55:5, 60:8, 65:15, 70:25, 75:40, 80:65}

DCl_4000 =  {45:3, 50:4, 55:5, 60:8, 65:15, 70:25, 75:40, 80:65}

DCl_2000 =  {45:1, 50:2, 55:3, 60:5, 65:10, 70:15, 75:25, 80:45}

DCl_1000 =  {45:1, 50:1, 55:2, 60:3, 65:5, 70:8, 75:10, 80:18}

DCl_500 =  {45:1, 50:1, 55:1, 60:1.5, 65:2, 70:2.5, 75:4, 80:6}

DCl_dict = {'10000':DCl_10000,'8000':DCl_8000,'4000':DCl_4000,'2000':DCl_2000,'1000':DCl_1000, '500':DCl_500 }

# %%
for name, data in DCl_dict.items():
    x = list(data.keys())
    y = list(data.values())

    # Plot the data points
    plt.scatter(x, y, label=name,s=80)

    # Calculate the equations of the lines connecting points
    equations = []
    for i in range(len(x) - 1):
        x1, y1 = x[i], y[i]
        x2, y2 = x[i + 1], y[i + 1]
        slope = (y2 - y1) / (x2 - x1)
        intercept = y1 - slope * x1
        equations.append(f"{slope:.2f}x + {intercept:.2f} for {x1} <= x <= {x2}")
    
    # Print the equations of the lines if you wish
    #for eq in equations:
    #    print(f"{name}: {eq}")

    # Plot the lines connecting points
    for i in range(len(x) - 1):
        plt.plot([x[i], x[i + 1]], [y[i], y[i + 1]], linestyle='-', color='blue')

# Add labels and legend
plt.xlabel('SiO2_Liq')
plt.ylabel('DCl')
plt.legend()
plt.show()

# Sample DataFrame 'systmass' with 'SiO2_Liq' and 'pressure_bar_str' columns
# Replace this with your actual DataFrame
syst_mass[['SiO2_Liq', 'pressure_bar_str']]

# Create a list to store calculated values
calculated_values = []


# Function to calculate DCl_calc for each row
def calculate_DCl_calc(row):
    melt_f = row['SiO2_Liq']
    pressure_bar_str = row['pressure_bar_str']

    # Check if pressure_bar_str exists in DCl_dict
    if pressure_bar_str in DCl_dict:
        equations = DCl_dict[pressure_bar_str]

        # Extract x values from the equation
        x_values = list(equations.keys())

        # Find the closest lower and upper x values in the equation
        closest_lower_x = max([x for x in x_values if x <= melt_f], default=None)
        closest_upper_x = min([x for x in x_values if x >= melt_f], default=None)

        if closest_lower_x is not None and closest_upper_x is not None:
            if closest_lower_x == closest_upper_x:
                # Handle the case where closest_upper_x and closest_lower_x are the same
                DCl_calc = equations[closest_lower_x]  # Use the value directly
            else:
                slope = (equations[closest_upper_x] - equations[closest_lower_x]) / (closest_upper_x - closest_lower_x)
                intercept = equations[closest_lower_x] - slope * closest_lower_x
                DCl_calc = slope * melt_f + intercept
            return DCl_calc

    return None



# Calculate DS_calc for each row and store it in the list
for index, row in syst_mass.iterrows():
    calculated_value = calculate_DCl_calc(row)
    calculated_values.append(calculated_value)

# Add the calculated values to the DataFrame
syst_mass['DCl_calc'] = calculated_values

# Print the updated DataFrame with DS_calc values
print(syst_mass[['pressure_bar_str','DCl_calc', 'SiO2_Liq']])


# Plot the scatter points
plt.scatter(x, y, label='DCl_calc', color='blue')

# Overlay the original equations as lines
for name, data in DCl_dict.items():
    x_values = list(data.keys())
    y_values = list(data.values())
    plt.plot(x_values, y_values, label=f'Original {name} Equation', linestyle='--')

plt.xlabel('SiO2')
plt.ylabel('DCl_calc')
plt.title('SiO2 vs. DCl_calc')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#      pressure_bar_str  DCl_calc   SiO2_Liq
# 0               10000  3.782807  48.914035
# 1               10000  3.769952  48.849762
# 2               10000  3.756972  48.784859
# 3               10000  3.744124  48.720622
# 4               10000  3.731405  48.657025
# ...               ...       ...        ...
# 2440              500  2.968586  71.561953
# 2441              500  3.070392  71.901307
# 2442              500  3.168720  72.229067
# 2443              500  3.263642  72.545473
# 2444              500  3.355249  72.850830
#
# [2445 rows x 3 columns]

# %%
# Append DCl_fluid-melt to the working dataframe
syst_mass['DCl_fm'] = syst_mass['DCl_calc']

# %% [markdown]
# ### Truncate melt fractions to 1 dp

# %%
import math
def truncate(number, decimals=1):
    """
    Returns a value truncated to a specific number of decimal places.
    """
    if not isinstance(decimals, int):
        raise TypeError("decimal places must be an integer.")
    elif decimals < 0:
        raise ValueError("decimal places has to be 0 or more.")
    elif decimals == 0:
        return math.trunc(number)

    factor = 10.0 ** decimals
    return math.trunc(number * factor) / factor

# %%
# create extra column for melt fraction truncated to 1 dp
syst_mass['meltf_1dp1'] = 0 
meltf_1dp = []

for i in range(len(syst_mass)):
    x = syst_mass['melt_f'][i]
    syst_mass['meltf_1dp1'] = truncate(x, decimals=1)
    meltf_1dp.append(syst_mass['meltf_1dp1'].loc[i])
syst_mass['meltf_1dp1'] = meltf_1dp

# %%
## INPUT INITIAL S and Cl CONCENTRATIONS HERE (PPM)
input_dict = {'S':1000, 'Cl':1000} 


for key,val in input_dict.items():
    print(key,val)
    # initial concentration (ppm) of S and Cl in system
    syst_mass['initial_'+ key] = val
    
    # bulk concentration (ppm) of S and Cl in system 
    syst_mass['bulk_'+ key +'_ppm'] = syst_mass['initial_'+ key] / syst_mass['melt_f']
    
    # mass (g) of S and Cl in melt + fluid 
    syst_mass['M_bulk_'+ key] = (syst_mass['fluid_cum_sum_H2O'] + syst_mass['mass_Liq'])*(syst_mass['bulk_'+ key +'_ppm']/10**6) 
      
    # G; mass fraction of S and Cl in the melt relative to the fluid
    syst_mass['G'] = syst_mass['mass_Liq'].div(syst_mass['fluid_cum_sum_H2O'])
    syst_mass['G'].replace([np.inf, -np.inf], 0, inplace=True)
# Out:
# S 1000
# Cl 1000

# %%
# export for resorption calculation 
# this will be used in 'Sulfide Resorption Modelling.ipynb'
syst_mass.to_csv('before_degassing_sulfsat.csv')

# %%
# Calculations for modelling S and Cl degassing:

Kd_dict = {'S':'DS_fm','Cl':'DCl_fm'} 
for key,val in Kd_dict.items():
    
    syst_mass[key] = syst_mass[val]  
for key,val in Kd_dict.items():
    
    # fluid-melt partition coefficient of S or Cl divided by respected G factor
    syst_mass[key +'_D/G'] = syst_mass[val].div(syst_mass['G'])
    syst_mass[key +'_D/G'].replace([np.inf, -np.inf], 0, inplace=True) # IMPORTANT FOR DRY CASE 

for key,val in Kd_dict.items(): 
    # mass (g) of S and Cl partitioning into fluid
    syst_mass['M_fluid_'+key] = syst_mass['M_bulk_'+ key]*(syst_mass[key +'_D/G'] / (syst_mass[key +'_D/G']+1))
    syst_mass['M_fluid_'+key].replace([np.inf, -np.inf], 0, inplace=True) 
    
for key,val in Kd_dict.items(): 
    # mass (g) of S and Cl in melt following fluid exsolution
    syst_mass['M_melt_'+key] = syst_mass['M_bulk_'+ key] - syst_mass['M_fluid_'+key]

for key,val in Kd_dict.items():    
    # check bulk mass (g) of S and Cl in fluid and melt
    syst_mass['M_bulk_'+key+'_check'] = (syst_mass['M_melt_'+key]+syst_mass['M_fluid_'+key]).div(syst_mass['M_bulk_'+ key])

for key,val in Kd_dict.items():
    # concentration (ppm) of S and Cl in fluid
    syst_mass['fluid_'+key+'_ppm'] = 1000000 * syst_mass['M_fluid_'+key].div(syst_mass['fluid_cum_sum_H2O'])
    
    syst_mass['fluid_'+key+'_ppm'] = syst_mass['fluid_'+key+'_ppm'].fillna(0)

for key,val in Kd_dict.items():    
    # concentration (ppm) of S and Cl in melt following fluid exsolution
    syst_mass['melt_'+key+'_ppm'] = 1000000 * syst_mass['M_melt_'+key].div(syst_mass['mass_Liq'])
    syst_mass['melt_'+key+'_ppm'] = syst_mass['melt_'+key+'_ppm'].fillna(0)

for key,val in Kd_dict.items():    
    # Cl molinity of fluid (moles/kg)
    syst_mass['mCl_fluid'] = 1000 * (syst_mass['M_fluid_Cl']/35)/syst_mass['fluid_cum_sum_H2O']
    
for key,val in Kd_dict.items():    
    # mole fraction Cl in fluid
    syst_mass['molXCl_fluid'] = 100 * (syst_mass['M_fluid_Cl']/35).div((syst_mass['M_fluid_Cl']/35) + (syst_mass['fluid_cum_sum_H2O']/18))
    
for key,val in Kd_dict.items():
    # NaCl (wt%) in fluid
    syst_mass['NaCl_fluid'] = 100*(((syst_mass['M_fluid_Cl']/35)*22.99)+syst_mass['M_fluid_Cl'])/syst_mass['fluid_cum_sum_H2O']

# %% [markdown]
# ## Modelling Degassing of chalcophile elements

# %%
## INPUT INITIAL CHALCOPHILE CONCENTRATIONS HERE (PPM)
input_metal_dict = {'Cu':75,'Ag':0.03,'Au':0.0033,'Se':0.14,'Re':0.001,'Te':0.5}

# calculating chalcophile fluid-melt partition coeffcients using published experimental data
# and parameterisations (see manuscript and SM1 references)


# Initialize all columns to 0
syst_mass['DCu_fm'] = 0
syst_mass['DAg_fm'] = 0
syst_mass['DAu_fm'] = 0
syst_mass['DSe_fm'] = 0
syst_mass['DTe_fm'] = 0
syst_mass['DRe_fm'] = 0

# Define a custom function to apply the conditions row-wise
def assign_values(row):
    #if row['M_exsol_H2O'] > 0:
    if row['fluid_cum_sum_H2O'] > 0:
        # fluid-melt partition coefficient for Cu
        row['DCu_fm'] = (30 * (row['NaCl_fluid'] - 0.4) / 8) + 2
        # Ag
        row['DAg_fm'] = 3 + (5 * row['mCl_fluid'])
        # Au
        row['DAu_fm'] = 100
        # Se
        row['DSe_fm'] = 55
        # Te
        row['DTe_fm'] = 75
        # Re
        row['DRe_fm'] = 4 * row['mCl_fluid']
    else:
        # Set all columns to 0
        row[['DCu_fm', 'DAg_fm','DAu_fm', 'DSe_fm', 'DTe_fm', 'DRe_fm']] = 0

    return row

# Apply the custom function row-wise to the dataframe
syst_mass = syst_mass.apply(assign_values, axis=1)

# %%
warnings.filterwarnings('ignore', category=pd.core.generic.SettingWithCopyWarning)
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)

metal_Kd_dict = {'Cu':'DCu_fm', 'Ag':'DAg_fm','Au':'DAu_fm',
                 'Se':'DSe_fm', 'Re':'DRe_fm','Te':'DTe_fm',
                 }                 

for key,val in metal_Kd_dict.items():
    #fluid-melt partition coefficient of chalcophile elements
    # divided by respected G factor
    syst_mass[key + '_D/G'] = syst_mass[val].div(syst_mass['G'])

for key,val in input_metal_dict.items():
    # initial chalcophile element concentration (ppm)
    syst_mass['initial_'+ key] = val
    
    # bulk chalcophile element concentration (ppm)
    syst_mass['bulk_'+ key +'_ppm'] = syst_mass['initial_'+ key] / (syst_mass['melt_f'] + syst_mass['fluid_cum_sum_H2O'])
    
    # bulk chalcophile element mass (g) 
    syst_mass['M_bulk_'+ key] = (syst_mass['fluid_cum_sum_H2O'] + syst_mass['mass_Liq'])*(syst_mass['bulk_'+ key +'_ppm']/10**6)
    
    # mass chalcophile element in fluid (g)
    syst_mass['M_fluid_'+key] = (syst_mass['M_bulk_'+ key]*syst_mass[key +'_D/G']) / (syst_mass[key +'_D/G']+1)
    syst_mass['M_fluid_'+key] = syst_mass['M_fluid_'+key].fillna(0)
    
    # mass chalcophile element remaining in the melt (g)
    syst_mass['M_melt_'+key] = syst_mass['M_bulk_'+ key] - syst_mass['M_fluid_'+key]
    
    # chalcophile element concentration (ppm) in fluid
    syst_mass['fluid_'+key+'_ppm'] = 1000000 * syst_mass['M_fluid_'+key].div(syst_mass['fluid_cum_sum_H2O'])#M_exsol_H2O
    
    # chalcophile element concentration (ppm) in melt
    syst_mass['melt_'+key+'_ppm'] = 1000000 * syst_mass['M_melt_'+key].div(syst_mass['mass_Liq'])

# %% [markdown]
# # Modelling the mass and concentration of chalcophiles partitioning into the sulfide phase

# %% [markdown]
# We assume sulfide to be present in the form of sulfide liquid at melt FeOt > 3.6 wt% and as MSS for melt FeOt < 3.6 wt%.
# We therefore employ both SL/melt partition coefficients (DX_sl) and MSS/melt partition coefficients (DX_mss) into our model at these given thresholds.

# %%
# Kiseeva and Wood 2013 - we choose to model using this parameterisation

syst_mass['DCu_sl'] = 10**((-0.823 * np.log10(syst_mass['FeOt_Liq'])) + 3.334)

syst_mass['DAg_sl'] = 10**((-0.819 * np.log10(syst_mass['FeOt_Liq'])) + 3.469)

# %%
# Kiseeva and Wood 2015 - alternative method

#syst_mass['DCu_sl'] = 10**((-0.5*np.log10(syst_mass['FeOt_Liq'])) + (4200/(syst_mass['T_C']+273.15)) + 0.7)

#syst_mass['DAg_sl'] = 10**((-0.5*np.log10(syst_mass['FeOt_Liq'])) + (4300/(syst_mass['T_C']+273.15)) + 0.724)

# %%
# chalcophile element sulfide-silicate melt partition coefficients 
# using Li and Audetat (2015) equation 

# sulfide liquid - silicate melt partition coeffcient for Cu
#syst_mass['DCu_sl'] = 10**(1.13+(0.39*(10000/(syst_mass['T_C']+273.15)))+(0.02*(syst_mass['DeltaQFM_frostbuff']))+(-0.86*np.log10(syst_mass['FeOt_Liq'])))

# monosulfide solid solution - silicate melt partition coeffcient for Cu
syst_mass['DCu_mss'] = 10**(1.18+(0.28*(10000/(syst_mass['T_C']+273.15)))+(-0.05*(syst_mass['DeltaQFM_frostbuff']))+(-0.66*np.log10(syst_mass['FeOt_Liq'])))

# Au
syst_mass['DAu_sl'] = 10**(3.18+(0.21*(10000/(syst_mass['T_C']+273.15)))+(0.08*(syst_mass['DeltaQFM_frostbuff']))+(-0.82*np.log10(syst_mass['FeOt_Liq'])))

syst_mass['DAu_mss'] = 10**(0.77+(0.21*(10000/(syst_mass['T_C']+273.15)))+(-0.17*(syst_mass['DeltaQFM_frostbuff']))+(-0.19*np.log10(syst_mass['FeOt_Liq'])))


# Ag
#syst_mass['DAg_sl'] = (10**(2.01+(0.16*(10000/(syst_mass['T_C']+273.15)))+(0.00*(syst_mass['DeltaQFM_frostbuff']))+(-0.16*np.log10(syst_mass['FeOt_Liq']))))

syst_mass['DAg_mss'] = 10**(0.73+(0.16*(10000/(syst_mass['T_C']+273.15)))+(-0.06*(syst_mass['DeltaQFM_frostbuff']))+(-0.34*np.log10(syst_mass['FeOt_Liq'])))


# Less experimental data are available for Re, Se and Te and their relationship with magma
# differentiation:

# Re from Li et al., (2021)
syst_mass['DRe_sl'] = 510
syst_mass['DRe_mss'] = 5900
            
# Se from Patten, 2019 (SL and MSS have simialr compatibility)
syst_mass['DSe_sl'] = 345 
syst_mass['DSe_mss'] = 345 

# Te from Li et al., (2021)
syst_mass['DTe_sl'] = 3300 
syst_mass['DTe_mss'] = 70

# %% [markdown]
# # Integrating SL and MSS
#
# sulf/sil melt partition coefficient are now defined
# FeOt > 3.6 we use the DX_sl
# FeOt < 3.6 we use the DX_mss

# %%
syst_mass['DCu_sulfsil'] = syst_mass.apply(lambda row: row['DCu_sl'] if row['FeOt_Liq'] > 3.6 else row['DCu_mss'], axis=1)
syst_mass['DAu_sulfsil'] = syst_mass.apply(lambda row: row['DAu_sl'] if row['FeOt_Liq'] > 3.6 else row['DAu_mss'], axis=1)
syst_mass['DAg_sulfsil'] = syst_mass.apply(lambda row: row['DAg_sl'] if row['FeOt_Liq'] > 3.6 else row['DAg_mss'], axis=1)
syst_mass['DSe_sulfsil'] = syst_mass.apply(lambda row: row['DSe_sl'] if row['FeOt_Liq'] > 3.6 else row['DSe_mss'], axis=1)
syst_mass['DRe_sulfsil'] = syst_mass.apply(lambda row: row['DRe_sl'] if row['FeOt_Liq'] > 3.6 else row['DRe_mss'], axis=1)

# %%
# optional plotting to compare differences in DX_sl versus DX_sulf/sil

from matplotlib.cm import viridis, cividis
from cmcrameri import cm
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

om_dict = {'H2O_0.1_QFM1.2':'#b3ecff','H2O_1.0_QFM1.2': '#33bbff', 'H2O_3.0_QFM1.2':'#0086b3', 'H2O_6.0_QFM1.2':'#001a33','H2O_0.0_QFM1.2':'red'}

pressure = syst_mass['pressure_bar'].unique()
lines = ['solid','solid','solid', 'dashdot', 'dashed', 'dotted']
#lines = ['solid', 'dashdot', 'dashed', 'dotted']
pdict = dict(zip(pressure, lines))

plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 16

fig, ax = plt.subplots(1, 2, figsize=(15, 9))


for v in syst_mass.newcolumn.unique():
    df_v = syst_mass[syst_mass.newcolumn == v]
    for p in [4000, 2000, 1000,500]:
        df_vp = df_v[df_v.pressure_bar == p]
        y = df_vp['DCu_sulfsil']
        x = df_vp['MgO_Liq']
        
        ax[0].plot(x, y, color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)
        ax[1].plot(x, df_vp['DCu_sl'],color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)

ax = ax.flatten()
for i in range(2):

    ax[i].tick_params(axis='both', which='both',top=True,right=True, labelsize=12, direction='in')
    ax[i].set_xlim(1.1,12.1)
    ax[i].grid(color='grey',which='both', alpha=0.1, zorder=0)
    ax[i].tick_params(axis='both', which='both', labelsize=15, direction='in', top=True,right=True)
    ax[i].set_xlabel('MgO wt%', fontsize=20,weight='bold')
    if i == 0:
        # plotting the combined sulfide liquid and MSS Kd
        ax[i].set_ylabel('DCu sulfide/melt', fontsize=20, weight='bold')
        ax[i].set_ylim(0,8000)
        
    if i == 1:
        # plotting sulfide liquid Kd
        ax[i].set_ylabel('DCu sl/melt', fontsize=20, weight='bold')
        ax[i].set_ylim(0,30000)

# %%
kd_comp = syst_mass[['T_C', 'SiO2_Liq', 'TiO2_Liq', 'Al2O3_Liq', 'Cr2O3_Liq',
       'Fe2O3_Liq', 'FeO_Liq', 'FeOt_Liq', 'MnO_Liq', 'MgO_Liq', 'CaO_Liq',
       'Na2O_Liq', 'K2O_Liq', 'P2O5_Liq', 'H2O_Liq', 'CO2_Liq', 'Fe3Fet_Liq',
       'h_Liq', 'mass_Liq', 'v_Liq', 'rho_Liq', 'pressure_bar', 'newcolumn',
       'index','G','DCu_fm','DRe_fm', 'DSe_fm', 'DTe_fm', 'DAg_fm','DAu_fm',
         'DCl_fm','DS_fm','NaCl_fluid']] 

kd_comp_sl = syst_mass[['T_C', 'SiO2_Liq', 'TiO2_Liq', 'Al2O3_Liq', 'Cr2O3_Liq',
       'Fe2O3_Liq', 'FeO_Liq', 'FeOt_Liq', 'MnO_Liq', 'MgO_Liq', 'CaO_Liq',
       'Na2O_Liq', 'K2O_Liq', 'P2O5_Liq', 'H2O_Liq', 'CO2_Liq', 'Fe3Fet_Liq',
       'h_Liq', 'mass_Liq', 'v_Liq', 'rho_Liq', 'pressure_bar', 'newcolumn',
       'index','G','DCu_sl','DAg_sl','DAu_sl','DCu_mss','DAg_mss','DAu_mss','DSe_mss', 
               'DRe_sl', 'DSe_sl','DRe_sl', 'DTe_sl', 'DRe_mss','DTe_mss',
                       'DCu_sulfsil','DAg_sulfsil','DAu_sulfsil','DSe_sulfsil','DRe_sulfsil',
                       ]]
kd_comp_sl.columns[25:]
# Out:
# Index(['DCu_sl', 'DAg_sl', 'DAu_sl', 'DCu_mss', 'DAg_mss', 'DAu_mss',
#        'DSe_mss', 'DRe_sl', 'DSe_sl', 'DRe_sl', 'DTe_sl', 'DRe_mss', 'DTe_mss',
#        'DCu_sulfsil', 'DAg_sulfsil', 'DAu_sulfsil', 'DSe_sulfsil',
#        'DRe_sulfsil'],
#       dtype='object')

# %%
kd_piv = pd.melt(kd_comp, id_vars=kd_comp.columns[:24], value_vars =kd_comp.columns[24:]).rename(columns = {'variable': 'Kd', 'value': 'value'}, inplace = False)
kd_piv = kd_piv.dropna(subset=['value'])

kd_piv_sl = pd.melt(kd_comp_sl, id_vars=kd_comp_sl.columns[:25], value_vars =kd_comp_sl.columns[25:]).rename(columns = {'variable': 'Kd', 'value': 'value'}, inplace = False)
kd_piv_sl = kd_piv_sl.dropna(subset=['value'])

sliced = kd_piv[kd_piv.pressure_bar.isin([4000])]
sliced_dp = kd_piv[kd_piv.pressure_bar.isin([1000])]

sliced_sl = kd_piv_sl[kd_piv_sl.pressure_bar.isin([4000])]
sliced_sl_dp = kd_piv_sl[kd_piv_sl.pressure_bar.isin([1000])]

# %%
# Plotting the relative volatility and sulfide affinity of the chalcophile elements modelled:

fig = plt.figure(figsize=(13,7)) 
ax = [fig.add_subplot(1,2,i+1) for i in range(2)]
plt.rcParams["font.family"] ="Arial" 

subcat_sl = ['DRe_sulfsil','DCu_sulfsil','DSe_sulfsil', 'DAg_sulfsil','DAu_sulfsil']
#subcat_sl = ['DRe_sl','DCu_sl','DSe_sl', 'DAg_sl','DAu_sl']
subcat_fm = ['DRe_fm','DCu_fm','DSe_fm', 'DAg_fm','DAu_fm']

subsubcat = ['H2O_6.0_QFM1.2'] 

subdict =  {'DCu_fm': (0.0, 1.0, 0.0),
           'DTe_fm': '#00264d',
 'DSe_fm': (1.0, 0.0, 1.0),
 'DRe_fm': (0.0, 0.5, 1.0),
 'DAg_fm': (1.0, 0.5, 0.0),
 'DAu_fm': (0.5, 0.0, 0.5),
           'DCl_fm': 'red',
           'DS_fm': 'blue'} 

# choose what you would like to project
subdict_sl = {'DCu_sulfsil': (0.0, 1.0, 0.0),'DSe_sulfsil': (1.0, 0.0, 1.0),'DRe_sulfsil': (0.0, 0.5, 1.0),'DAg_sulfsil': (1.0, 0.5, 0.0),'DAu_sulfsil': (0.5, 0.0, 0.5)}
#subdict_sl = {'DCu_sl': (0.0, 1.0, 0.0),'DSe_sl': (1.0, 0.0, 1.0),'DRe_sl': (0.0, 0.5, 1.0),'DAg_sl': (1.0, 0.5, 0.0),'DAu_sl': (0.5, 0.0, 0.5)}



linedict = dict(zip(subsubcat, ['solid', 'dashdot', 'dashed','dotted', 'solid']))
for i in subcat_fm:
        dfh = sliced_dp[sliced_dp['Kd'] == i]
        
        for j in subsubcat:
            fin = dfh[dfh.newcolumn == j]
            fin['value'] = fin['value'].replace(0, np.nan)
            x = fin['MgO_Liq']
            y = fin['value']
            ax[0].plot(x,y, color=subdict[i], linestyle='--', label=i, alpha=1)
            
for i in subcat_sl:
        dfh = sliced_sl_dp[sliced_sl_dp['Kd'] == i]
        
        for j in subsubcat:
            fin = dfh[dfh.newcolumn == j]
            x = fin['MgO_Liq']
            y = fin['value']
            ax[1].plot(x,y, color=subdict_sl[i], linestyle='--', label=i, alpha=1)

for i in subcat_fm:
        dfh = sliced[sliced['Kd'] == i]
        
        for j in subsubcat:
            fin = dfh[dfh.newcolumn == j]
            fin['value'] = fin['value'].replace(0, np.nan)
            x = fin['MgO_Liq']
            y = fin['value']
            ax[0].plot(x,y, color=subdict[i], linestyle='-', label=i, alpha=1,zorder=3)
            
for i in subcat_sl:
        dfh = sliced_sl[sliced_sl['Kd'] == i]
        
        for j in subsubcat:
            fin = dfh[dfh.newcolumn == j]
            x = fin['MgO_Liq']
            y = fin['value']
            ax[1].plot(x,y, color=subdict_sl[i], linestyle='-', label=i, alpha=1, zorder=3)
            
            

            
##### overlay SL only data:
subcat_sl = ['DRe_sl','DCu_sl','DSe_sl', 'DAg_sl','DAu_sl']
subdict_sl = {'DCu_sl': (0.0, 1.0, 0.0),'DSe_sl': (1.0, 0.0, 1.0),'DRe_sl': (0.0, 0.5, 1.0),'DAg_sl': (1.0, 0.5, 0.0),'DAu_sl': (0.5, 0.0, 0.5)}
for i in subcat_sl:
        dfh = sliced_sl_dp[sliced_sl_dp['Kd'] == i]
        
        for j in subsubcat:
            fin = dfh[dfh.newcolumn == j]
            x = fin['MgO_Liq']
            y = fin['value']
            ax[1].plot(x,y, color=subdict_sl[i], linestyle='--', linewidth=2,label=i, alpha=0.2)
for i in subcat_sl:
        dfh = sliced_sl[sliced_sl['Kd'] == i]
        
        for j in subsubcat:
            fin = dfh[dfh.newcolumn == j]
            x = fin['MgO_Liq']
            y = fin['value']
            ax[1].plot(x,y, color=subdict_sl[i], linestyle='-',linewidth=2, label=i, alpha=0.2, zorder=3)

            
            
for i in range(2):
    ax[i].set_xlabel('MgO wt%',fontsize=20,weight='bold' )
    
    ax[i].grid(color='grey',which='both', alpha=0.1, zorder=0)
    ax[i].set_xlim(1,12)
    ax[i].set_yscale('log')
    ax[i].tick_params(axis='both', which='both', labelsize=20, direction='in', top=True,right=True)
    ax[1].set_yticks([100, 1000,10000,1e5])#,1e5, 1e6])
    ax[0].set_yticks([0.1, 1, 10, 100])

        
# Legend plotting
from matplotlib.lines import Line2D
color =list(subdict.values())
line_pressure = [Line2D([0], [0], color=color[0],lw=3, linestyle='-',alpha=0.8),
                Line2D([0], [0], color=color[3],lw=3,  linestyle='-',alpha=0.8),
                Line2D([0], [0], color=color[2],lw=3,  linestyle='-',alpha=0.8),
               
                 Line2D([0], [0], color=color[4],lw=3, linestyle='-',alpha=0.8),
                 Line2D([0], [0], color=color[5],lw=3, linestyle='-',alpha=0.8),
            
                 Line2D([0], [0], color='k',lw=2,),
                 Line2D([0], [0], color='k',lw=2,linestyle='--')]

ax[1].legend(line_pressure,['Cu','Re','Se','Ag','Au' ,'400 MPa','100 MPa'],  fontsize=12,
                 frameon=True,edgecolor='k', borderpad=0.8, ncol=1,loc = 'upper right',framealpha=1)

#ax[0].annotate(r'e.g. for $H_{2}O$ 6.0 wt%', xy=(0.55, 0.72), fontsize=15, xycoords='axes fraction', color='black', zorder=5)
ax[0].annotate('a.D fluid/melt', xy=(0.05, 0.06), fontsize=22, xycoords='axes fraction', color='black', weight='bold',zorder=5)
ax[1].annotate('b.D sl/melt', xy=(0.05, 0.06), fontsize=22, xycoords='axes fraction', color='black', weight='bold',zorder=5)
plt.tight_layout()

# %% [markdown]
# # Modelling sulfide saturation

# %% [markdown]
# Here we calculate the mass and concentration of sulfide and sulphate forming and the corresponding mass and concentration of S and chaclophile elements within the sulfide liquid, melt and fluid phases.
#
# We perform iterative calcualtions that evaluate whether the melt is still sulfide saturated at each step.
#
# without this re-equilibration step, the mass fraction of fluid is over-estimated and sulfide under-estimated.

# %%
# iterated output should have the same shape as original dataframe
syst_mass.shape
# Out:
# (2445, 492)

# %%
dfnew = syst_mass.copy()

# %%
# Check that our penultimate column has non NaN values - this is important - if no fluid then should be 0.0
# for the iteration loop below.  
for u in dfnew.unique.unique():
    syst_mass = dfnew[dfnew['unique'].isin([u])].copy()
    print(f"Penultimate row of DataFrame {u}:\n", syst_mass['S_D/G'].iloc[-2])
# Out:
# Penultimate row of DataFrame P_10000.0_H2O_0.1_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_10000.0_H2O_0.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_10000.0_H2O_6.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_10000.0_H2O_3.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_10000.0_H2O_1.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_8000.0_H2O_0.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_8000.0_H2O_6.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_8000.0_H2O_3.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_8000.0_H2O_0.1_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_8000.0_H2O_1.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_4000.0_H2O_0.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_4000.0_H2O_6.0_QFM1.2:
#  1.0944432425610366
# Penultimate row of DataFrame P_4000.0_H2O_3.0_QFM1.2:
#  0.02503979416966002
# Penultimate row of DataFrame P_4000.0_H2O_1.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_4000.0_H2O_0.1_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_2000.0_H2O_3.0_QFM1.2:
#  0.15026889793073264
# Penultimate row of DataFrame P_2000.0_H2O_0.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_2000.0_H2O_6.0_QFM1.2:
#  2.9115198955463195
# Penultimate row of DataFrame P_2000.0_H2O_1.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_2000.0_H2O_0.1_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_1000.0_H2O_0.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_1000.0_H2O_3.0_QFM1.2:
#  3.9622356382208728
# Penultimate row of DataFrame P_1000.0_H2O_1.0_QFM1.2:
#  0.504015289449783
# Penultimate row of DataFrame P_1000.0_H2O_6.0_QFM1.2:
#  9.298011454117846
# Penultimate row of DataFrame P_500.0_H2O_0.0_QFM1.2:
#  0.0
# Penultimate row of DataFrame P_500.0_H2O_6.0_QFM1.2:
#  27.94130252924442
# Penultimate row of DataFrame P_500.0_H2O_3.0_QFM1.2:
#  12.881914388769792
# Penultimate row of DataFrame P_500.0_H2O_1.0_QFM1.2:
#  3.9434871457355603

# %%
warnings.filterwarnings('ignore', category=pd.core.generic.SettingWithCopyWarning)
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)

# Define columns to be filled in this loop and changed
dfnew[['melt_S2_ppm', 'satmelt_S2_ppm', 'melt_S6_ppm', 'GG', 'S_sulfide_ppm', 'M_S_sulfide','DS_sulfsil', 'DS_sl', 'DS_mss',
           'M_S_sulf_cumu', 'melt_Stot_ppm', 'M_satmelt_S', 'sulfide_Cu_ppm']] = 0.0

# Change depending on model requirements
eqbm_dict = {'S': 1000, 'Cu': 75,'Ag':0.03,'Au':0.0033,'Se':0.14,'Re':0.001}
#metal_sulfide_dict = {'Cu':'DCu_mss','Re':'DRe_mss','Se':'DSe_mss','Te':'DTe_mss', 'Ag':'DAg_mss', 'Au':'DAu_mss'}
metal_sulfide_dict = {'Cu':'DCu_sulfsil','Re':'DRe_sulfsil','Se':'DSe_sulfsil','Ag':'DAg_sulfsil', 'Au':'DAu_sulfsil'}
#metal_sulfide_dict = {'Cu':'DCu_sl','Re':'DRe_sl','Se':'DSe_sl','Ag':'DAg_sl', 'Au':'DAu_sl'}


# Create an empty dictionary to store DataFrames
result_dataframes = {}

max_iterations = 100  # Set the desired number of iterations

for u in dfnew.unique.unique():
    syst_mass = dfnew[dfnew['unique'].isin([u])].copy()
    
    # Initialize a counter for testing
    iteration_counter = 0
    condition_met = True
    
    while condition_met: 

        if iteration_counter == 0:
            syst_mass['melt_S2_ppm'] = syst_mass['melt_S_ppm'] * (1 - syst_mass['jugo_s6st'])
        else:
            syst_mass['melt_S2_ppm'] = syst_mass['new_Cmelt_S2']
        # Calculate S_sulfide_ppm and satmelt_S2_ppm
        syst_mass['S_sulfide_ppm'] = syst_mass['melt_S2_ppm'].sub(syst_mass['SCSS_OM21']).clip(0)
        syst_mass['satmelt_S2_ppm'] = syst_mass['melt_S2_ppm'].sub(syst_mass['S_sulfide_ppm'])

        # Calculate M_S_sulfide and M_S_sulf_cumu
        syst_mass['M_S_sulfide'] = (syst_mass['mass_Liq'] + syst_mass['fluid_cum_sum_H2O']) * syst_mass['S_sulfide_ppm'] / 10 ** 6
        
        syst_mass['M_S_sulf_cumu'] += syst_mass['M_S_sulfide']

        # Calculate melt_S6_ppm
        syst_mass['melt_S6_ppm'] = syst_mass['melt_S_ppm'] * syst_mass['jugo_s6st']
        syst_mass['melt_S6_ppm'] = syst_mass['melt_S6_ppm'].where(syst_mass['melt_S6_ppm'] < syst_mass['SCAS'], syst_mass['SCAS'])

        # Calculate melt_Stot_ppm and M_satmelt_S
        syst_mass['melt_Stot_ppm'] = syst_mass['melt_S6_ppm'] + syst_mass['satmelt_S2_ppm']
        syst_mass['M_satmelt_S'] = syst_mass['melt_Stot_ppm'] * (syst_mass['mass_Liq'] / 10 ** 6)

        # Calculate DS_sulfsil or DS_sl or DS_mss - depends on what you would like to model
        syst_mass['DS_sulfsil'] = 50 / (syst_mass['melt_Stot_ppm'] / 10000)
        

        # Calculate GG
        syst_mass['GG'] = syst_mass['mass_Liq'] / (2 * syst_mass['M_S_sulfide']).where(syst_mass['M_S_sulfide'] > 0, 0)

        # Calculate metal_sulfide_dict
        for key, val in metal_sulfide_dict.items():
            syst_mass[key + '_D/GG'] = syst_mass[val] / syst_mass['GG'].where(syst_mass['GG'] > 0, 1)

            syst_mass['totM_' + key + '_sulfide+melt'] = ((2 * syst_mass['M_S_sulfide']) + syst_mass['mass_Liq']) * syst_mass['melt_' + key + '_ppm'] / 10**6
            syst_mass['M_' + key + '_sulfide'] = syst_mass['totM_' + key + '_sulfide+melt'] * syst_mass[key + '_D/GG'] / (syst_mass[key + '_D/GG'] + 1)
            syst_mass['M_melt_' + key + '_final'] = syst_mass['totM_' + key + '_sulfide+melt'] - syst_mass['M_' + key + '_sulfide']

            # concentration (ppm) of chalcophile element in melt after sulfide phase and fluids formed
            syst_mass['melt_'+key+'_ppm_final'] = 1000000 * syst_mass['M_melt_'+key+'_final'].div(syst_mass['mass_Liq'])

            syst_mass['sulfide_' + key + '_ppm'] = 1000000 * syst_mass['M_' + key + '_sulfide'] / (2 * syst_mass['M_S_sulfide']).where(syst_mass['M_' + key + '_sulfide'] > 0, 0)


        # equilibration steps
        # calcualting the mass fraction of fluid (Xfluid), sulfide (Xsulf), melt (Xmelt) and solids (Xsolid) in the system 
        syst_mass['Xfluid'] = syst_mass['fluid_cum_sum_H2O'].div(syst_mass['i_M_fluid']+syst_mass['i_M_melt']+syst_mass['i_M_solid'])

        syst_mass['Xsulf'] = (2*syst_mass['M_S_sulf_cumu']).div(syst_mass['i_M_fluid']+syst_mass['i_M_melt']+syst_mass['i_M_solid'])

        syst_mass['Xmelt'] = syst_mass['mass_Liq'].div(syst_mass['i_M_fluid']+syst_mass['i_M_melt']+syst_mass['i_M_solid'])

        syst_mass['Xsolid'] = syst_mass['M_solid'].div(syst_mass['i_M_fluid']+syst_mass['i_M_melt']+syst_mass['i_M_solid'])

        syst_mass['Xtotal'] = syst_mass['Xfluid'] + syst_mass['Xsulf'] + syst_mass['Xmelt'] + syst_mass['Xsolid']

        syst_mass['Xfluid_norm'] = syst_mass['Xfluid'] / syst_mass['Xtotal']

        syst_mass['Xsulf_norm'] = syst_mass['Xsulf'] / syst_mass['Xtotal']

        syst_mass['Xmelt_norm'] = syst_mass['Xmelt'] / syst_mass['Xtotal']

        syst_mass['Xsolid_norm'] = syst_mass['Xsolid'] / syst_mass['Xtotal']

        syst_mass['Xtotal_norm'] = syst_mass['Xtotal'] / syst_mass['Xtotal']

        for key, val in eqbm_dict.items():
            # CiXi is the total system mass of a given element
            syst_mass['CiXi_' + key] = (val / 10000) * syst_mass['Xtotal_norm']
            
            # equilibrated concentration of element in melt, wt%
            # change 'D'+key+'_sl' term to 'D'+key+'_mss' or 'D'+key+'_sulfsil' if desired
            syst_mass['new_Cmelt_' + key] = syst_mass['CiXi_' + key] / (syst_mass['Xmelt_norm'] + (syst_mass['Xfluid_norm'] * syst_mass['D' +key+'_fm']) + (syst_mass['Xsulf_norm'] * syst_mass['D'+key+'_sulfsil']))
            # equilibrated concentration of element in fluid, wt%
            syst_mass['new_Cfluid_' + key] = np.where(syst_mass['Xfluid_norm'] == 0, 0,syst_mass['D'+key+'_fm'] * syst_mass['new_Cmelt_' + key])
            # equilibrated concentration of element in sulfide, wt%
            # change 'D'+key+'_sl' term to 'D'+key+'_mss' or 'D'+key+'_sulfsil' if desired
            syst_mass['new_Csulf_' + key] = np.where(syst_mass['Xsulf_norm'] == 0, 0,syst_mass['D'+key+'_sulfsil'] * syst_mass['new_Cmelt_' + key])
            # equilibrated mass of element in melt, g
            syst_mass['new_Mmelt_'+key] = syst_mass['new_Cmelt_'+key] * syst_mass['Xmelt_norm']
            # equilibrated mass of element in fluid, g
            syst_mass['new_Mfluid_'+key] = syst_mass['new_Cfluid_'+key] *syst_mass['Xfluid_norm']
            # equilibrated mass of element in sulfide, g
            syst_mass['new_Msulf_'+key] = syst_mass['new_Csulf_'+key] *syst_mass['Xsulf_norm']
            # check mass balance is adhered to
            syst_mass['new_tot_mass_check_'+key] = syst_mass['new_Mmelt_'+key] + syst_mass['new_Mfluid_'+key] + syst_mass['new_Msulf_'+key]
            # new melt concentration of S2-, after we have equilibrated
            syst_mass['new_Cmelt_S2'] = 10**4 * syst_mass['new_Cmelt_S'] * (1 - syst_mass['jugo_s6st'])
            # check that condition is met
            syst_mass['condition_check'] = syst_mass['new_Cmelt_S2'] / syst_mass['SCSS_OM21']

        print(f"Iteration {iteration_counter} condition value:", syst_mass['new_Cmelt_S2'].iloc[-2]/(syst_mass['SCSS_OM21'].iloc[-2]))

        # Check if the last value is within 1% of SCSS
        if syst_mass['new_Cmelt_S2'].iloc[-2]/syst_mass['SCSS_OM21'].iloc[-2] < 1.001:
            print("Breaking the loop due to the last value being within 1% of SCSS")
            break

        # Check the condition for the while loop
        condition_met = iteration_counter < max_iterations
        iteration_counter += 1
    
    
    # Store resulting df in the dictionary
    result_dataframes[u] = syst_mass.copy()
    
# Print the number of iterations completed for each dataframe
for key, df in result_dataframes.items():
    print(f"Number of iterations completed for DataFrame {key}: {df.shape[0]}")
# Display the tail of the DataFrame
#syst_mass.tail()
# Out:
# Iteration 0 condition value: 2.6480868912552755
# Iteration 1 condition value: 2.251854254866211
# Iteration 2 condition value: 2.022141085033735
# Iteration 3 condition value: 1.8667194618964482
# Iteration 4 condition value: 1.752538469456307
# Iteration 5 condition value: 1.6641808116742252
# Iteration 6 condition value: 1.5933004570622353
# Iteration 7 condition value: 1.5349150966320633
# Iteration 8 condition value: 1.485835306919585
# Iteration 9 condition value: 1.4439090581462841
# Iteration 10 condition value: 1.4076232233402428
# Iteration 11 condition value: 1.3758779988807277
# Iteration 12 condition value: 1.3478518448925092
# Iteration 13 condition value: 1.322916844182808
# Iteration 14 condition value: 1.3005836052526114
# Iteration 15 condition value: 1.2804642265610975
# Iteration 16 condition value: 1.2622467063874336
# Iteration 17 condition value: 1.2456768336693897
# Iteration 18 condition value: 1.2305451018079065
# Iteration 19 condition value: 1.2166770756808094
# Iteration 20 condition value: 1.2039261828840535
# Iteration 21 condition value: 1.1921682389042398
# Iteration 22 condition value: 1.1812972334533263
# Iteration 23 condition value: 1.1712220480937867
# Iteration 24 condition value: 1.1618638710807891
# Iteration 25 condition value: 1.1531541407640395
# Iteration 26 condition value: 1.1450328943160768
# Iteration 27 condition value: 1.137447430582675
# Iteration 28 condition value: 1.1303512187546423
# Iteration 29 condition value: 1.1237030011520837
# Iteration 30 condition value: 1.1174660505764518
# Iteration 31 condition value: 1.1116075517035109
# Iteration 32 condition value: 1.1060980827449773
# Iteration 33 condition value: 1.1009111787150392
# Iteration 34 condition value: 1.096022961536302
# Iteration 35 condition value: 1.0914118252198453
# Iteration 36 condition value: 1.087058166681256
# Iteration 37 condition value: 1.082944154573237
# Iteration 38 condition value: 1.079053529946704
# Iteration 39 condition value: 1.0753714336862683
# Iteration 40 condition value: 1.0718842565699802
# Iteration 41 condition value: 1.0685795085282257
# Iteration 42 condition value: 1.0654457042613261
# Iteration 43 condition value: 1.0624722628494851
# Iteration 44 condition value: 1.05964941937505
# Iteration 45 condition value: 1.0569681468934473
# Iteration 46 condition value: 1.0544200873494045
# Iteration 47 condition value: 1.05199749025017
# Iteration 48 condition value: 1.0496931580858762
# Iteration 49 condition value: 1.0475003976359047
# Iteration 50 condition value: 1.045412976424461
# Iteration 51 condition value: 1.043425083692951
# Iteration 52 condition value: 1.0415312953447122
# Iteration 53 condition value: 1.0397265423919786
# Iteration 54 condition value: 1.0380060824980106
# Iteration 55 condition value: 1.036365474260957
# Iteration 56 condition value: 1.0348005539317757
# Iteration 57 condition value: 1.0333074142977206
# Iteration 58 condition value: 1.0318823854965014
# Iteration 59 condition value: 1.0305220175551573
# Iteration 60 condition value: 1.0292230644726434
# Iteration 61 condition value: 1.0279824696866984
# Iteration 62 condition value: 1.0267973527843004
# Iteration 63 condition value: 1.0256649973312622
# Iteration 64 condition value: 1.0245828397106975
# Iteration 65 condition value: 1.0235484588724533
# Iteration 66 condition value: 1.0225595669064247
# Iteration 67 condition value: 1.0216140003621526
# Iteration 68 condition value: 1.0207097122454432
# Iteration 69 condition value: 1.0198447646300661
# Iteration 70 condition value: 1.0190173218290757
# Iteration 71 condition value: 1.0182256440759878
# Iteration 72 condition value: 1.0174680816711206
# Iteration 73 condition value: 1.0167430695528712
# Iteration 74 condition value: 1.016049122257687
# Iteration 75 condition value: 1.0153848292360277
# Iteration 76 condition value: 1.0147488504947622
# Iteration 77 condition value: 1.0141399125392634
# Iteration 78 condition value: 1.0135568045909658
# Iteration 79 condition value: 1.0129983750584035
# Iteration 80 condition value: 1.0124635282417696
# Iteration 81 condition value: 1.011951221252824
# Iteration 82 condition value: 1.0114604611336249
# Iteration 83 condition value: 1.010990302158993
# Iteration 84 condition value: 1.0105398433089687
# Iteration 85 condition value: 1.010108225898669
# Iteration 86 condition value: 1.0096946313540547
# Iteration 87 condition value: 1.0092982791230718
# Iteration 88 condition value: 1.008918424712514
# Iteration 89 condition value: 1.0085543578417442
# Iteration 90 condition value: 1.0082054007051366
# Iteration 91 condition value: 1.0078709063357574
# Iteration 92 condition value: 1.007550257063392
# Iteration 93 condition value: 1.0072428630605814
# Iteration 94 condition value: 1.0069481609708002
# Iteration 95 condition value: 1.0066656126133926
# Iteration 96 condition value: 1.0063947037602599
# Iteration 97 condition value: 1.0061349429796949
# Iteration 98 condition value: 1.0058858605430885
# Iteration 99 condition value: 1.0056470073905512
# Iteration 100 condition value: 1.0054179541517816
# Iteration 0 condition value: 1.726112760048229
# Iteration 1 condition value: 1.6939240730449217
# Iteration 2 condition value: 1.664265190895152
# Iteration 3 condition value: 1.6368314502224635
# Iteration 4 condition value: 1.6113671876772315
# Iteration 5 condition value: 1.5876560371543857
# Iteration 6 condition value: 1.5655134797601196
# Iteration 7 condition value: 1.5447810526292816
# Iteration 8 condition value: 1.525321796515822
# Iteration 9 condition value: 1.5070166403520915
# Iteration 10 condition value: 1.4897615028363467
# Iteration 11 condition value: 1.4734649486611056
# Iteration 12 condition value: 1.4580462780405836
# Iteration 13 condition value: 1.4434339578564053
# Iteration 14 condition value: 1.42956432443746
# Iteration 15 condition value: 1.4163805040406974
# Iteration 16 condition value: 1.4038315090991456
# Iteration 17 condition value: 1.3918714773622518
# Iteration 18 condition value: 1.3804590279550895
# Iteration 19 condition value: 1.3695567136861049
# Iteration 20 condition value: 1.3591305530407558
# Iteration 21 condition value: 1.3491496285042828
# Iteration 22 condition value: 1.339585740376725
# Iteration 23 condition value: 1.330413107237317
# Iteration 24 condition value: 1.3216081058032971
# Iteration 25 condition value: 1.3131490442003142
# Iteration 26 condition value: 1.3050159636865948
# Iteration 27 condition value: 1.2971904647033379
# Iteration 28 condition value: 1.2896555537998962
# Iteration 29 condition value: 1.282395508535504
# Iteration 30 condition value: 1.2753957579140767
# Iteration 31 condition value: 1.2686427762841357
# Iteration 32 condition value: 1.2621239889473157
# Iteration 33 condition value: 1.2558276879781782
# Iteration 34 condition value: 1.24974295697481
# Iteration 35 condition value: 1.2438596036414937
# Iteration 36 condition value: 1.2381680992578692
# Iteration 37 condition value: 1.2326595242183407
# Iteration 38 condition value: 1.2273255189351533
# Iteration 39 condition value: 1.2221582394918165
# Iteration 40 condition value: 1.2171503175130747
# Iteration 41 condition value: 1.2122948237856896
# Iteration 42 condition value: 1.2075852352226562
# Iteration 43 condition value: 1.2030154048137116
# Iteration 44 condition value: 1.1985795342482897
# Iteration 45 condition value: 1.1942721489345516
# Iteration 46 condition value: 1.1900880751705603
# Iteration 47 condition value: 1.1860224192519113
# Iteration 48 condition value: 1.1820705483246665
# Iteration 49 condition value: 1.17822807281391
# Iteration 50 condition value: 1.174490830276979
# Iteration 51 condition value: 1.1708548705468822
# Iteration 52 condition value: 1.1673164420458417
# Iteration 53 condition value: 1.1638719791616212
# Iteration 54 condition value: 1.1605180905904884
# Iteration 55 condition value: 1.157251548560568
# Iteration 56 condition value: 1.1540692788580997
# Iteration 57 condition value: 1.1509683515868714
# Iteration 58 condition value: 1.1479459725980032
# Iteration 59 condition value: 1.144999475533372
# Iteration 60 condition value: 1.1421263144314522
# Iteration 61 condition value: 1.1393240568491925
# Iteration 62 condition value: 1.1365903774579278
# Iteration 63 condition value: 1.1339230520752093
# Iteration 64 condition value: 1.1313199520979282
# Iteration 65 condition value: 1.128779039305249
# Iteration 66 condition value: 1.1262983610026769
# Iteration 67 condition value: 1.12387604548112
# Iteration 68 condition value: 1.121510297767099
# Iteration 69 condition value: 1.1191993956422963
# Iteration 70 condition value: 1.1169416859125276
# Iteration 71 condition value: 1.1147355809078667
# Iteration 72 condition value: 1.112579555197206
# Iteration 73 condition value: 1.1104721425019026
# Iteration 74 condition value: 1.108411932794416
# Iteration 75 condition value: 1.1063975695689798
# Iteration 76 condition value: 1.1044277472723898
# Iteration 77 condition value: 1.1025012088839268
# Iteration 78 condition value: 1.1006167436343035
# Iteration 79 condition value: 1.0987731848542868
# Iteration 80 condition value: 1.096969407944389
# Iteration 81 condition value: 1.0952043284576578
# Iteration 82 condition value: 1.0934769002881934
# Iteration 83 condition value: 1.0917861139585807
# Iteration 84 condition value: 1.0901309949999158
# Iteration 85 condition value: 1.088510602418568
# Iteration 86 condition value: 1.0869240272442533
# Iteration 87 condition value: 1.0853703911543633
# Iteration 88 condition value: 1.08384884516987
# Iteration 89 condition value: 1.0823585684184482
# Iteration 90 condition value: 1.0808987669607564
# Iteration 91 condition value: 1.0794686726761051
# Iteration 92 condition value: 1.078067542203994
# Iteration 93 condition value: 1.0766946559382373
# Iteration 94 condition value: 1.0753493170706192
# Iteration 95 condition value: 1.0740308506812235
# Iteration 96 condition value: 1.0727386028727668
# Iteration 97 condition value: 1.0714719399464507
# Iteration 98 condition value: 1.0702302476169836
# Iteration 99 condition value: 1.069012930264613
# Iteration 100 condition value: 1.067819410222103
# Iteration 0 condition value: 1.3040247065378183
# Iteration 1 condition value: 1.218963603417617
# Iteration 2 condition value: 1.1642741458034678
# Iteration 3 condition value: 1.1263648788473448
# Iteration 4 condition value: 1.0988447561070687
# Iteration 5 condition value: 1.0782390366137893
# Iteration 6 condition value: 1.0624695511315392
# Iteration 7 condition value: 1.050206292934686
# Iteration 8 condition value: 1.040553991618434
# Iteration 9 condition value: 1.032886138846193
# Iteration 10 condition value: 1.0267507085099121
# Iteration 11 condition value: 1.021813518965553
# Iteration 12 condition value: 1.0178226104981498
# Iteration 13 condition value: 1.014584962787093
# Iteration 14 condition value: 1.0119507722643348
# Iteration 15 condition value: 1.0098025321370292
# Iteration 16 condition value: 1.0080472612621456
# Iteration 17 condition value: 1.0066108556796964
# Iteration 18 condition value: 1.0054339067606453
# Iteration 19 condition value: 1.0044685552564725
# Iteration 20 condition value: 1.003676091613615
# Iteration 21 condition value: 1.003025103491537
# Iteration 22 condition value: 1.0024900309167675
# Iteration 23 condition value: 1.0020500294081733
# Iteration 24 condition value: 1.0016880686944858
# Iteration 25 condition value: 1.0013902136426858
# Iteration 26 condition value: 1.0011450474680759
# Iteration 27 condition value: 1.0009432069747963
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 2.0193029664401965
# Iteration 1 condition value: 1.723033067062754
# Iteration 2 condition value: 1.5606439978635258
# Iteration 3 condition value: 1.4543756373381809
# Iteration 4 condition value: 1.378320763240791
# Iteration 5 condition value: 1.3208170065138578
# Iteration 6 condition value: 1.275688348153816
# Iteration 7 condition value: 1.2393036790881649
# Iteration 8 condition value: 1.2093647597489812
# Iteration 9 condition value: 1.1843345582878924
# Iteration 10 condition value: 1.1631400974901533
# Iteration 11 condition value: 1.145006156021425
# Iteration 12 condition value: 1.1293566204164394
# Iteration 13 condition value: 1.1157531372515888
# Iteration 14 condition value: 1.1038554386534596
# Iteration 15 condition value: 1.0933948228840396
# Iteration 16 condition value: 1.0841559200844173
# Iteration 17 condition value: 1.0759638440965202
# Iteration 18 condition value: 1.068674943391099
# Iteration 19 condition value: 1.0621700157390892
# Iteration 20 condition value: 1.0563492457992716
# Iteration 21 condition value: 1.0511283706874783
# Iteration 22 condition value: 1.0464357358299892
# Iteration 23 condition value: 1.0422100062859447
# Iteration 24 condition value: 1.0383983674461823
# Iteration 25 condition value: 1.0349550957873845
# Iteration 26 condition value: 1.0318404127382694
# Iteration 27 condition value: 1.0290195574792742
# Iteration 28 condition value: 1.0264620307326369
# Iteration 29 condition value: 1.0241409733314761
# Iteration 30 condition value: 1.0220326519371141
# Iteration 31 condition value: 1.0201160306205965
# Iteration 32 condition value: 1.0183724117679438
# Iteration 33 condition value: 1.0167851333486189
# Iteration 34 condition value: 1.0153393123130934
# Iteration 35 condition value: 1.0140216259793704
# Iteration 36 condition value: 1.0128201248895017
# Iteration 37 condition value: 1.0117240718816034
# Iteration 38 condition value: 1.0107238031161512
# Iteration 39 condition value: 1.009810607580741
# Iteration 40 condition value: 1.008976622222491
# Iteration 41 condition value: 1.0082147403575263
# Iteration 42 condition value: 1.0075185314097292
# Iteration 43 condition value: 1.006882170356895
# Iteration 44 condition value: 1.0063003755276014
# Iteration 45 condition value: 1.0057683536088962
# Iteration 46 condition value: 1.005281750902954
# Iteration 47 condition value: 1.004836610017791
# Iteration 48 condition value: 1.0044293312988446
# Iteration 49 condition value: 1.0040566384095637
# Iteration 50 condition value: 1.00371554755378
# Iteration 51 condition value: 1.0034033399036308
# Iteration 52 condition value: 1.0031175368565977
# Iteration 53 condition value: 1.0028558777957148
# Iteration 54 condition value: 1.002616300069868
# Iteration 55 condition value: 1.0023969209475443
# Iteration 56 condition value: 1.002196021328536
# Iteration 57 condition value: 1.0020120310247669
# Iteration 58 condition value: 1.001843515444338
# Iteration 59 condition value: 1.001689163532648
# Iteration 60 condition value: 1.0015477768415353
# Iteration 61 condition value: 1.0014182596122123
# Iteration 62 condition value: 1.001299609770652
# Iteration 63 condition value: 1.0011909107453367
# Iteration 64 condition value: 1.0010913240271098
# Iteration 65 condition value: 1.0010000823994933
# Iteration 66 condition value: 1.000916483775425
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 1.8855696998870386
# Iteration 1 condition value: 1.742684274809228
# Iteration 2 condition value: 1.638557930791199
# Iteration 3 condition value: 1.5584970760928092
# Iteration 4 condition value: 1.4946278704869935
# Iteration 5 condition value: 1.4422828315141618
# Iteration 6 condition value: 1.3984895915339983
# Iteration 7 condition value: 1.3612506617577438
# Iteration 8 condition value: 1.329166121419311
# Iteration 9 condition value: 1.3012211645249223
# Iteration 10 condition value: 1.2766594455661464
# Iteration 11 condition value: 1.254903988003992
# Iteration 12 condition value: 1.2355058540104011
# Iteration 13 condition value: 1.218109729297358
# Iteration 14 condition value: 1.2024301967181856
# Iteration 15 condition value: 1.1882349789071909
# Iteration 16 condition value: 1.175332849989896
# Iteration 17 condition value: 1.1635647510189882
# Iteration 18 condition value: 1.1527971506166956
# Iteration 19 condition value: 1.1429170090068468
# Iteration 20 condition value: 1.1338279066150483
# Iteration 21 condition value: 1.1254470315224316
# Iteration 22 condition value: 1.1177028091452303
# Iteration 23 condition value: 1.110533018253528
# Iteration 24 condition value: 1.1038832795619817
# Iteration 25 condition value: 1.0977058327861067
# Iteration 26 condition value: 1.0919585392429851
# Iteration 27 condition value: 1.0866040624054107
# Iteration 28 condition value: 1.0816091900463494
# Iteration 29 condition value: 1.0769442699263039
# Iteration 30 condition value: 1.0725827371993508
# Iteration 31 condition value: 1.0685007164162013
# Iteration 32 condition value: 1.064676684588434
# Iteration 33 condition value: 1.0610911845355735
# Iteration 34 condition value: 1.0577265798742006
# Iteration 35 condition value: 1.0545668446776326
# Iteration 36 condition value: 1.0515973821476663
# Iteration 37 condition value: 1.0488048676794035
# Iteration 38 condition value: 1.046177112528444
# Iteration 39 condition value: 1.0437029449535784
# Iteration 40 condition value: 1.0413721062432324
# Iteration 41 condition value: 1.0391751594675473
# Iteration 42 condition value: 1.037103409151211
# Iteration 43 condition value: 1.0351488303512633
# Iteration 44 condition value: 1.0333040058618348
# Iteration 45 condition value: 1.0315620704641357
# Iteration 46 condition value: 1.029916661302874
# Iteration 47 condition value: 1.0283618736059121
# Iteration 48 condition value: 1.026892221077359
# Iteration 49 condition value: 1.0255026003894407
# Iteration 50 condition value: 1.024188259278605
# Iteration 51 condition value: 1.0229447678190167
# Iteration 52 condition value: 1.0217679925039909
# Iteration 53 condition value: 1.0206540728147007
# Iteration 54 condition value: 1.019599399997134
# Iteration 55 condition value: 1.0186005978038815
# Iteration 56 condition value: 1.0176545049878656
# Iteration 57 condition value: 1.0167581593614257
# Iteration 58 condition value: 1.0159087832568034
# Iteration 59 condition value: 1.0151037702436805
# Iteration 60 condition value: 1.014340672976393
# Iteration 61 condition value: 1.0136171920581987
# Iteration 62 condition value: 1.0129311658228117
# Iteration 63 condition value: 1.012280560944627
# Iteration 64 condition value: 1.011663463798851
# Iteration 65 condition value: 1.0110780725013597
# Iteration 66 condition value: 1.0105226895656065
# Iteration 67 condition value: 1.0099957151205812
# Iteration 68 condition value: 1.0094956406396258
# Iteration 69 condition value: 1.0090210431351008
# Iteration 70 condition value: 1.0085705797784443
# Iteration 71 condition value: 1.0081429829092257
# Iteration 72 condition value: 1.0077370554003715
# Iteration 73 condition value: 1.0073516663499447
# Iteration 74 condition value: 1.006985747072698
# Iteration 75 condition value: 1.0066382873671527
# Iteration 76 condition value: 1.0063083320362232
# Iteration 77 condition value: 1.005994977641432
# Iteration 78 condition value: 1.0056973694725746
# Iteration 79 condition value: 1.0054146987163213
# Iteration 80 condition value: 1.0051461998087035
# Iteration 81 condition value: 1.0048911479577534
# Iteration 82 condition value: 1.0046488568237482
# Iteration 83 condition value: 1.00441867634557
# Iteration 84 condition value: 1.0041999907026815
# Iteration 85 condition value: 1.0039922164030601
# Iteration 86 condition value: 1.0037948004882542
# Iteration 87 condition value: 1.003607218847415
# Iteration 88 condition value: 1.0034289746328307
# Iteration 89 condition value: 1.0032595967700648
# Iteration 90 condition value: 1.003098638556345
# Iteration 91 condition value: 1.0029456763413418
# Iteration 92 condition value: 1.002800308284914
# Iteration 93 condition value: 1.0026621531868172
# Iteration 94 condition value: 1.0025308493837324
# Iteration 95 condition value: 1.0024060537093222
# Iteration 96 condition value: 1.002287440513331
# Iteration 97 condition value: 1.0021747007360302
# Iteration 98 condition value: 1.0020675410345725
# Iteration 99 condition value: 1.00196568295807
# Iteration 100 condition value: 1.0018688621684098
# Iteration 0 condition value: 1.6023887196173465
# Iteration 1 condition value: 1.448198112545299
# Iteration 2 condition value: 1.3514751200723978
# Iteration 3 condition value: 1.284232148971832
# Iteration 4 condition value: 1.2345689084781393
# Iteration 5 condition value: 1.1963935540390724
# Iteration 6 condition value: 1.1662056186360894
# Iteration 7 condition value: 1.1418262688255822
# Iteration 8 condition value: 1.121816935583632
# Iteration 9 condition value: 1.1051836699938526
# Iteration 10 condition value: 1.0912144739102438
# Iteration 11 condition value: 1.0793841065409868
# Iteration 12 condition value: 1.0692955401221116
# Iteration 13 condition value: 1.0606424481492949
# Iteration 14 condition value: 1.0531843271038428
# Iteration 15 condition value: 1.0467295040266245
# Iteration 16 condition value: 1.0411232310051604
# Iteration 17 condition value: 1.0362391558704416
# Iteration 18 condition value: 1.0319730902708457
# Iteration 19 condition value: 1.028238375839877
# Iteration 20 condition value: 1.024962384057885
# Iteration 21 condition value: 1.0220838346544951
# Iteration 22 condition value: 1.019550714491865
# Iteration 23 condition value: 1.0173186433845716
# Iteration 24 condition value: 1.015349577007803
# Iteration 25 condition value: 1.013610767158133
# Iteration 26 condition value: 1.0120739207138256
# Iteration 27 condition value: 1.010714513617466
# Iteration 28 condition value: 1.0095112269842612
# Iteration 29 condition value: 1.0084454802958434
# Iteration 30 condition value: 1.0075010424304314
# Iteration 31 condition value: 1.0066637055943475
# Iteration 32 condition value: 1.0059210104655694
# Iteration 33 condition value: 1.0052620133247314
# Iteration 34 condition value: 1.0046770878369515
# Iteration 35 condition value: 1.0041577556060635
# Iteration 36 condition value: 1.003696540757896
# Iteration 37 condition value: 1.0032868446993934
# Iteration 38 condition value: 1.00292283790341
# Iteration 39 condition value: 1.0025993661280839
# Iteration 40 condition value: 1.0023118689271795
# Iteration 41 condition value: 1.0020563086682186
# Iteration 42 condition value: 1.0018291085673219
# Iteration 43 condition value: 1.0016270984877442
# Iteration 44 condition value: 1.0014474674442666
# Iteration 45 condition value: 1.0012877219164484
# Iteration 46 condition value: 1.0011456492070154
# Iteration 47 condition value: 1.001019285192618
# Iteration 48 condition value: 1.0009068859070434
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 1.5785531107683146
# Iteration 1 condition value: 1.4244165730198046
# Iteration 2 condition value: 1.3292235040755618
# Iteration 3 condition value: 1.263721881729393
# Iteration 4 condition value: 1.2157378017906406
# Iteration 5 condition value: 1.179115965058877
# Iteration 6 condition value: 1.1503484109974875
# Iteration 7 condition value: 1.1272645810968405
# Iteration 8 condition value: 1.1084378838906024
# Iteration 9 condition value: 1.092886250730222
# Iteration 10 condition value: 1.0799083559420293
# Iteration 11 condition value: 1.0689882265582291
# Iteration 12 condition value: 1.059736802286664
# Iteration 13 condition value: 1.0518546092367171
# Iteration 14 condition value: 1.0451070699204417
# Iteration 15 condition value: 1.0393076764663693
# Iteration 16 condition value: 1.03430622264897
# Iteration 17 condition value: 1.0299803857394354
# Iteration 18 condition value: 1.0262295832200479
# Iteration 19 condition value: 1.0229704092010925
# Iteration 20 condition value: 1.0201331898360249
# Iteration 21 condition value: 1.0176593456748055
# Iteration 22 condition value: 1.0154993454007006
# Iteration 23 condition value: 1.0136110994010306
# Iteration 24 condition value: 1.01195868489714
# Iteration 25 condition value: 1.010511324132791
# Iteration 26 condition value: 1.0092425579338202
# Iteration 27 condition value: 1.008129571715446
# Iteration 28 condition value: 1.007152641627014
# Iteration 29 condition value: 1.0062946762490612
# Iteration 30 condition value: 1.0055408349453996
# Iteration 31 condition value: 1.0048782082059673
# Iteration 32 condition value: 1.0042955484983596
# Iteration 33 condition value: 1.0037830425608896
# Iteration 34 condition value: 1.0033321179192127
# Iteration 35 condition value: 1.0029352778365521
# Iteration 36 condition value: 1.0025859600193718
# Iteration 37 condition value: 1.0022784152725945
# Iteration 38 condition value: 1.0020076029879705
# Iteration 39 condition value: 1.0017691008980885
# Iteration 40 condition value: 1.001559026968504
# Iteration 41 condition value: 1.0013739716554502
# Iteration 42 condition value: 1.0012109390448654
# Iteration 43 condition value: 1.0010672956239577
# Iteration 44 condition value: 1.0009407256300136
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 2.374354298936722
# Iteration 1 condition value: 2.0014737118970163
# Iteration 2 condition value: 1.7959898950085502
# Iteration 3 condition value: 1.6605119428569426
# Iteration 4 condition value: 1.5627072949521958
# Iteration 5 condition value: 1.4880471177739403
# Iteration 6 condition value: 1.4288452532607305
# Iteration 7 condition value: 1.3805854441954604
# Iteration 8 condition value: 1.3404101952090504
# Iteration 9 condition value: 1.3064087759489043
# Iteration 10 condition value: 1.2772473923256038
# Iteration 11 condition value: 1.25196232394585
# Iteration 12 condition value: 1.229837259292712
# Iteration 13 condition value: 1.210327031837604
# Iteration 14 condition value: 1.193008307671809
# Iteration 15 condition value: 1.1775466275873447
# Iteration 16 condition value: 1.1636737474211605
# Iteration 17 condition value: 1.1511716724077004
# Iteration 18 condition value: 1.13986116437784
# Iteration 19 condition value: 1.1295933107943474
# Iteration 20 condition value: 1.1202432350309566
# Iteration 21 condition value: 1.1117053328957598
# Iteration 22 condition value: 1.1038896157856661
# Iteration 23 condition value: 1.096718868688514
# Iteration 24 condition value: 1.0901264166303912
# Iteration 25 condition value: 1.084054351272319
# Iteration 26 condition value: 1.0784521095848336
# Iteration 27 condition value: 1.073275324811235
# Iteration 28 condition value: 1.0684848901018145
# Iteration 29 condition value: 1.0640461897786264
# Iteration 30 condition value: 1.059928463853538
# Iteration 31 condition value: 1.0561042793106956
# Iteration 32 condition value: 1.052549087561552
# Iteration 33 condition value: 1.0492408519321963
# Iteration 34 condition value: 1.0461597324339
# Iteration 35 condition value: 1.0432878176733051
# Iteration 36 condition value: 1.0406088957766344
# Iteration 37 condition value: 1.0381082577769976
# Iteration 38 condition value: 1.0357725281514225
# Iteration 39 condition value: 1.0335895181733474
# Iteration 40 condition value: 1.0315480985258774
# Iteration 41 condition value: 1.0296380882454998
# Iteration 42 condition value: 1.0278501575689416
# Iteration 43 condition value: 1.026175742663177
# Iteration 44 condition value: 1.024606970550197
# Iteration 45 condition value: 1.0231365928093976
# Iteration 46 condition value: 1.021757926863348
# Iteration 47 condition value: 1.0204648038367017
# Iteration 48 condition value: 1.019251522130559
# Iteration 49 condition value: 1.0181128059815248
# Iteration 50 condition value: 1.0170437683807927
# Iteration 51 condition value: 1.0160398778175317
# Iteration 52 condition value: 1.0150969283857316
# Iteration 53 condition value: 1.0142110128568798
# Iteration 54 condition value: 1.0133784983744076
# Iteration 55 condition value: 1.012596004471377
# Iteration 56 condition value: 1.0118603831516904
# Iteration 57 condition value: 1.0111687008082835
# Iteration 58 condition value: 1.010518221780223
# Iteration 59 condition value: 1.0099063933750745
# Iteration 60 condition value: 1.009330832204006
# Iteration 61 condition value: 1.0087893116953013
# Iteration 62 condition value: 1.0082797506677392
# Iteration 63 condition value: 1.0078002028590025
# Iteration 64 condition value: 1.007348847316205
# Iteration 65 condition value: 1.0069239795660314
# Iteration 66 condition value: 1.006524003491062
# Iteration 67 condition value: 1.0061474238468526
# Iteration 68 condition value: 1.0057928393612892
# Iteration 69 condition value: 1.0054589363639277
# Iteration 70 condition value: 1.0051444828984166
# Iteration 71 condition value: 1.004848323275904
# Iteration 72 condition value: 1.0045693730315521
# Iteration 73 condition value: 1.0043066142500412
# Iteration 74 condition value: 1.004059091229263
# Iteration 75 condition value: 1.0038259064543746
# Iteration 76 condition value: 1.0036062168570166
# Iteration 77 condition value: 1.0033992303368477
# Iteration 78 condition value: 1.0032042025246573
# Iteration 79 condition value: 1.0030204337681992
# Iteration 80 condition value: 1.0028472663235708
# Iteration 81 condition value: 1.002684081736484
# Iteration 82 condition value: 1.0025302983991335
# Iteration 83 condition value: 1.0023853692695956
# Iteration 84 condition value: 1.0022487797418005
# Iteration 85 condition value: 1.0021200456551096
# Iteration 86 condition value: 1.0019987114334565
# Iteration 87 condition value: 1.001884348344801
# Iteration 88 condition value: 1.0017765528724085
# Iteration 89 condition value: 1.0016749451901394
# Iteration 90 condition value: 1.0015791677345343
# Iteration 91 condition value: 1.001488883867057
# Iteration 92 condition value: 1.0014037766203503
# Iteration 93 condition value: 1.001323547522839
# Iteration 94 condition value: 1.00124791549643
# Iteration 95 condition value: 1.0011766158224467
# Iteration 96 condition value: 1.0011093991713058
# Iteration 97 condition value: 1.0010460306917484
# Iteration 98 condition value: 1.0009862891557606
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 1.6608836512500367
# Iteration 1 condition value: 1.596859386121089
# Iteration 2 condition value: 1.5431386658480795
# Iteration 3 condition value: 1.4973023945910613
# Iteration 4 condition value: 1.4576602079293388
# Iteration 5 condition value: 1.422989665583244
# Iteration 6 condition value: 1.3923814307745341
# Iteration 7 condition value: 1.365142925088937
# Iteration 8 condition value: 1.340735980989851
# Iteration 9 condition value: 1.318735141631879
# Iteration 10 condition value: 1.298798971675811
# Iteration 11 condition value: 1.2806498310218104
# Iteration 12 condition value: 1.2640593067652257
# Iteration 13 condition value: 1.2488375205881066
# Iteration 14 condition value: 1.2348251477871843
# Iteration 15 condition value: 1.2218873700671211
# Iteration 16 condition value: 1.2099092311046657
# Iteration 17 condition value: 1.1987920254839084
# Iteration 18 condition value: 1.1884504595842555
# Iteration 19 condition value: 1.178810396520964
# Iteration 20 condition value: 1.169807048151276
# Iteration 21 condition value: 1.1613835129703114
# Iteration 22 condition value: 1.1534895842713218
# Iteration 23 condition value: 1.1460807714156762
# Iteration 24 condition value: 1.1391174905736752
# Iteration 25 condition value: 1.1325643912991434
# Iteration 26 condition value: 1.1263897927800561
# Iteration 27 condition value: 1.1205652092551883
# Iteration 28 condition value: 1.1150649483904433
# Iteration 29 condition value: 1.1098657697161285
# Iteration 30 condition value: 1.1049465927888429
# Iteration 31 condition value: 1.1002882467418396
# Iteration 32 condition value: 1.0958732544600769
# Iteration 33 condition value: 1.0916856458605464
# Iteration 34 condition value: 1.087710795749518
# Iteration 35 condition value: 1.083935282522354
# Iteration 36 condition value: 1.0803467646113576
# Iteration 37 condition value: 1.0769338721054136
# Iteration 38 condition value: 1.0736861113872647
# Iteration 39 condition value: 1.0705937809795898
# Iteration 40 condition value: 1.067647897074988
# Iteration 41 condition value: 1.0648401274593946
# Iteration 42 condition value: 1.0621627327328695
# Iteration 43 condition value: 1.0596085138935687
# Iteration 44 condition value: 1.0571707654860034
# Iteration 45 condition value: 1.054843233628214
# Iteration 46 condition value: 1.0526200783280482
# Iteration 47 condition value: 1.0504958395794992
# Iteration 48 condition value: 1.048465406798487
# Iteration 49 condition value: 1.0465239912156765
# Iteration 50 condition value: 1.0446671008935753
# Iteration 51 condition value: 1.042890518077596
# Iteration 52 condition value: 1.0411902786272245
# Iteration 53 condition value: 1.0395626533047408
# Iteration 54 condition value: 1.0380041307259904
# Iteration 55 condition value: 1.0365114018010482
# Iteration 56 condition value: 1.035081345512876
# Iteration 57 condition value: 1.0337110158996838
# Iteration 58 condition value: 1.0323976301219968
# Iteration 59 condition value: 1.031138557508832
# Iteration 60 condition value: 1.0299313094890643
# Iteration 61 condition value: 1.0287735303243122
# Iteration 62 condition value: 1.0276629885686914
# Iteration 63 condition value: 1.0265975691886717
# Iteration 64 condition value: 1.025575266283287
# Iteration 65 condition value: 1.0245941763510975
# Iteration 66 condition value: 1.0236524920557522
# Iteration 67 condition value: 1.0227484964468532
# Iteration 68 condition value: 1.0218805575971004
# Iteration 69 condition value: 1.021047123620513
# Iteration 70 condition value: 1.0202467180399353
# Iteration 71 condition value: 1.0194779354750503
# Iteration 72 condition value: 1.0187394376248433
# Iteration 73 condition value: 1.0180299495208824
# Iteration 74 condition value: 1.0173482560299452
# Iteration 75 condition value: 1.016693198586477
# Iteration 76 condition value: 1.0160636721371117
# Iteration 77 condition value: 1.0154586222810649
# Iteration 78 condition value: 1.0148770425916205
# Iteration 79 condition value: 1.014317972105216
# Iteration 80 condition value: 1.0137804929657879
# Iteration 81 condition value: 1.013263728213071
# Iteration 82 condition value: 1.0127668397045124
# Iteration 83 condition value: 1.012289026161288
# Iteration 84 condition value: 1.0118295213297166
# Iteration 85 condition value: 1.0113875922500482
# Iteration 86 condition value: 1.0109625376252527
# Iteration 87 condition value: 1.0105536862830282
# Iteration 88 condition value: 1.0101603957247622
# Iteration 89 condition value: 1.0097820507556743
# Iteration 90 condition value: 1.0094180621908158
# Iteration 91 condition value: 1.0090678656319894
# Iteration 92 condition value: 1.0087309203110464
# Iteration 93 condition value: 1.008406707995326
# Iteration 94 condition value: 1.0080947319513462
# Iteration 95 condition value: 1.00779451596311
# Iteration 96 condition value: 1.0075056034016696
# Iteration 97 condition value: 1.007227556342826
# Iteration 98 condition value: 1.0069599547300574
# Iteration 99 condition value: 1.0067023955799828
# Iteration 100 condition value: 1.0064544922278424
# Iteration 0 condition value: 2.159874137371429
# Iteration 1 condition value: 1.9630862491749097
# Iteration 2 condition value: 1.8250290872247983
# Iteration 3 condition value: 1.7213337630711316
# Iteration 4 condition value: 1.6398743279514951
# Iteration 5 condition value: 1.5738103625724738
# Iteration 6 condition value: 1.518938719194069
# Iteration 7 condition value: 1.4725103371363784
# Iteration 8 condition value: 1.4326391678751051
# Iteration 9 condition value: 1.39798132309821
# Iteration 10 condition value: 1.3675492979509338
# Iteration 11 condition value: 1.3405986921074788
# Iteration 12 condition value: 1.3165561380729036
# Iteration 13 condition value: 1.2949717858125862
# Iteration 14 condition value: 1.2754870144815094
# Iteration 15 condition value: 1.2578119120403668
# Iteration 16 condition value: 1.2417092071083768
# Iteration 17 condition value: 1.2269825733455835
# Iteration 18 condition value: 1.2134679645704662
# Iteration 19 condition value: 1.2010270930719007
# Iteration 20 condition value: 1.1895424508827896
# Iteration 21 condition value: 1.1789134599405948
# Iteration 22 condition value: 1.1690534603205682
# Iteration 23 condition value: 1.1598873289540996
# Iteration 24 condition value: 1.1513495784465193
# Iteration 25 condition value: 1.1433828255653846
# Iteration 26 condition value: 1.1359365472977654
# Iteration 27 condition value: 1.1289660627334657
# Iteration 28 condition value: 1.1224316938475443
# Iteration 29 condition value: 1.1162980691647506
# Iteration 30 condition value: 1.1105335424082032
# Iteration 31 condition value: 1.1051097043391733
# Iteration 32 condition value: 1.1000009706276386
# Iteration 33 condition value: 1.0951842321401433
# Iteration 34 condition value: 1.0906385567694499
# Iteration 35 condition value: 1.0863449340603686
# Iteration 36 condition value: 1.0822860555552116
# Iteration 37 condition value: 1.0784461250991528
# Iteration 38 condition value: 1.0748106943916007
# Iteration 39 condition value: 1.0713665199052889
# Iteration 40 condition value: 1.0681014379663847
# Iteration 41 condition value: 1.0650042553316432
# Iteration 42 condition value: 1.0620646530395481
# Iteration 43 condition value: 1.059273101672368
# Iteration 44 condition value: 1.0566207864613595
# Iteration 45 condition value: 1.0540995409107163
# Iteration 46 condition value: 1.0517017878172774
# Iteration 47 condition value: 1.049420486730385
# Iteration 48 condition value: 1.047249087035976
# Iteration 49 condition value: 1.0451814859659445
# Iteration 50 condition value: 1.0432119909321584
# Iteration 51 condition value: 1.041335285667456
# Iteration 52 condition value: 1.0395463997261463
# Iteration 53 condition value: 1.037840680956152
# Iteration 54 condition value: 1.0362137706056904
# Iteration 55 condition value: 1.0346615807707795
# Iteration 56 condition value: 1.0331802739269786
# Iteration 57 condition value: 1.0317662443207305
# Iteration 58 condition value: 1.030416101023139
# Iteration 59 condition value: 1.0291266524727702
# Iteration 60 condition value: 1.0278948923546232
# Iteration 61 condition value: 1.0267179866802587
# Iteration 62 condition value: 1.0255932619495778
# Iteration 63 condition value: 1.0245181942882922
# Iteration 64 condition value: 1.0234903994669258
# Iteration 65 condition value: 1.0225076237175503
# Iteration 66 condition value: 1.0215677352735284
# Iteration 67 condition value: 1.0206687165655224
# Iteration 68 condition value: 1.0198086570140523
# Iteration 69 condition value: 1.0189857463650878
# Iteration 70 condition value: 1.0181982685206497
# Iteration 71 condition value: 1.0174445958212344
# Iteration 72 condition value: 1.0167231837411976
# Iteration 73 condition value: 1.0160325659620508
# Iteration 74 condition value: 1.0153713497920236
# Iteration 75 condition value: 1.014738211903296
# Iteration 76 condition value: 1.0141318943609916
# Iteration 77 condition value: 1.0135512009204635
# Iteration 78 condition value: 1.0129949935715588
# Iteration 79 condition value: 1.0124621893104997
# Iteration 80 condition value: 1.0119517571217576
# Iteration 81 condition value: 1.0114627151538726
# Iteration 82 condition value: 1.0109941280745733
# Iteration 83 condition value: 1.0105451045918272
# Iteration 84 condition value: 1.0101147951286138
# Iteration 85 condition value: 1.0097023896402182
# Iteration 86 condition value: 1.00930711556382
# Iteration 87 condition value: 1.0089282358909675
# Iteration 88 condition value: 1.0085650473543244
# Iteration 89 condition value: 1.0082168787207548
# Iteration 90 condition value: 1.007883089183462
# Iteration 91 condition value: 1.0075630668464666
# Iteration 92 condition value: 1.0072562272952366
# Iteration 93 condition value: 1.0069620122477672
# Iteration 94 condition value: 1.0066798882808365
# Iteration 95 condition value: 1.0064093456265706
# Iteration 96 condition value: 1.0061498970348084
# Iteration 97 condition value: 1.0059010766971086
# Iteration 98 condition value: 1.0056624392285178
# Iteration 99 condition value: 1.0054335587035301
# Iteration 100 condition value: 1.0052140277429058
# Iteration 0 condition value: 2.2219137741726818
# Iteration 1 condition value: 2.100955333527807
# Iteration 2 condition value: 2.0027279639269984
# Iteration 3 condition value: 1.9209348405988163
# Iteration 4 condition value: 1.8514901284939596
# Iteration 5 condition value: 1.791607733775559
# Iteration 6 condition value: 1.739312011011434
# Iteration 7 condition value: 1.6931568777794457
# Iteration 8 condition value: 1.652055726749599
# Iteration 9 condition value: 1.6151738280980612
# Iteration 10 condition value: 1.5818577323845961
# Iteration 11 condition value: 1.551587492691601
# Iteration 12 condition value: 1.5239434570476096
# Iteration 13 condition value: 1.4985826467941068
# Iteration 14 condition value: 1.475221608430818
# Iteration 15 condition value: 1.4536237386557693
# Iteration 16 condition value: 1.4335897640503539
# Iteration 17 condition value: 1.41495048641909
# Iteration 18 condition value: 1.397561182184936
# Iteration 19 condition value: 1.381297227355467
# Iteration 20 condition value: 1.366050642879202
# Iteration 21 condition value: 1.3517273397497405
# Iteration 22 condition value: 1.3382449021348277
# Iteration 23 condition value: 1.3255307884932666
# Iteration 24 condition value: 1.313520860545325
# Iteration 25 condition value: 1.3021581716874293
# Iteration 26 condition value: 1.2913919624127563
# Iteration 27 condition value: 1.2811768221689703
# Iteration 28 condition value: 1.2714719859961292
# Iteration 29 condition value: 1.262240741042532
# Iteration 30 condition value: 1.2534499232217202
# Iteration 31 condition value: 1.2450694882569422
# Iteration 32 condition value: 1.2370721444547608
# Iteration 33 condition value: 1.2294330369728417
# Iteration 34 condition value: 1.2221294752572955
# Iteration 35 condition value: 1.215140696840793
# Iteration 36 condition value: 1.20844766190298
# Iteration 37 condition value: 1.2020328739666974
# Iteration 38 condition value: 1.1958802228885201
# Iteration 39 condition value: 1.1899748469394305
# Iteration 40 condition value: 1.1843030112914825
# Iteration 41 condition value: 1.1788520006526737
# Iteration 42 condition value: 1.1736100241434197
# Iteration 43 condition value: 1.1685661307985487
# Iteration 44 condition value: 1.1637101343200271
# Iteration 45 condition value: 1.1590325459069326
# Iteration 46 condition value: 1.1545245141576745
# Iteration 47 condition value: 1.1501777711810488
# Iteration 48 condition value: 1.1459845841721312
# Iteration 49 condition value: 1.1419377118100043
# Iteration 50 condition value: 1.1380303649200794
# Iteration 51 condition value: 1.1342561709167738
# Iteration 52 condition value: 1.130609141604666
# Iteration 53 condition value: 1.1270836439696459
# Iteration 54 condition value: 1.1236743736374708
# Iteration 55 condition value: 1.1203763307166092
# Iteration 56 condition value: 1.1171847977763936
# Iteration 57 condition value: 1.1140953197410102
# Iteration 58 condition value: 1.1111036855054748
# Iteration 59 condition value: 1.1082059111020346
# Iteration 60 condition value: 1.1053982242648421
# Iteration 61 condition value: 1.1026770502577317
# Iteration 62 condition value: 1.1000389988447665
# Iteration 63 condition value: 1.0974808522962727
# Iteration 64 condition value: 1.094999554334521
# Iteration 65 condition value: 1.0925921999332948
# Iteration 66 condition value: 1.090256025894517
# Iteration 67 condition value: 1.087988402132937
# Iteration 68 condition value: 1.0857868236068786
# Iteration 69 condition value: 1.0836489028392087
# Iteration 70 condition value: 1.081572362978193
# Iteration 71 condition value: 1.0795550313527902
# Iteration 72 condition value: 1.0775948334812766
# Iteration 73 condition value: 1.0756897874960145
# Iteration 74 condition value: 1.0738379989506193
# Iteration 75 condition value: 1.072037655978925
# Iteration 76 condition value: 1.0702870247779175
# Iteration 77 condition value: 1.0685844453893256
# Iteration 78 condition value: 1.0669283277568062
# Iteration 79 condition value: 1.065317148037695
# Iteration 80 condition value: 1.06374944515012
# Iteration 81 condition value: 1.0622238175379244
# Iteration 82 condition value: 1.0607389201373438
# Iteration 83 condition value: 1.059293461530729
# Iteration 84 condition value: 1.0578862012738242
# Iteration 85 condition value: 1.0565159473842267
# Iteration 86 condition value: 1.0551815539796627
# Iteration 87 condition value: 1.053881919055614
# Iteration 88 condition value: 1.0526159823926813
# Iteration 89 condition value: 1.0513827235848154
# Iteration 90 condition value: 1.0501811601802469
# Iteration 91 condition value: 1.049010345927566
# Iteration 92 condition value: 1.0478693691199934
# Iteration 93 condition value: 1.0467573510313952
# Iteration 94 condition value: 1.0456734444380924
# Iteration 95 condition value: 1.0446168322209437
# Iteration 96 condition value: 1.043586726042592
# Iteration 97 condition value: 1.0425823650951378
# Iteration 98 condition value: 1.0416030149138422
# Iteration 99 condition value: 1.0406479662527695
# Iteration 100 condition value: 1.0397165340185837
# Iteration 0 condition value: 2.366231791878338
# Iteration 1 condition value: 2.1256977492017692
# Iteration 2 condition value: 1.9614435962829382
# Iteration 3 condition value: 1.8400272009783047
# Iteration 4 condition value: 1.7456281248883927
# Iteration 5 condition value: 1.6696063373316696
# Iteration 6 condition value: 1.6067723334118014
# Iteration 7 condition value: 1.553788924269579
# Iteration 8 condition value: 1.5083964250271202
# Iteration 9 condition value: 1.4690015163906942
# Iteration 10 condition value: 1.4344434105681643
# Iteration 11 condition value: 1.4038533177862766
# Iteration 12 condition value: 1.376566098365466
# Iteration 13 condition value: 1.3520626007062242
# Iteration 14 condition value: 1.3299308136799377
# Iteration 15 condition value: 1.309838971916027
# Iteration 16 condition value: 1.2915164907158878
# Iteration 17 condition value: 1.27474016810753
# Iteration 18 condition value: 1.2593240141246067
# Iteration 19 condition value: 1.2451116303362864
# Iteration 20 condition value: 1.231970415934044
# Iteration 21 condition value: 1.2197871039910484
# Iteration 22 condition value: 1.2084642810757382
# Iteration 23 condition value: 1.1979176438174997
# Iteration 24 condition value: 1.188073814683582
# Iteration 25 condition value: 1.1788685869623152
# Iteration 26 condition value: 1.1702455026445138
# Iteration 27 condition value: 1.1621546910163139
# Iteration 28 condition value: 1.1545519132674562
# Iteration 29 condition value: 1.147397771253796
# Iteration 30 condition value: 1.1406570480756657
# Iteration 31 condition value: 1.1342981552721612
# Iteration 32 condition value: 1.1282926668341164
# Iteration 33 condition value: 1.1226149243642185
# Iteration 34 condition value: 1.117241700889883
# Iteration 35 condition value: 1.1121519133005249
# Iteration 36 condition value: 1.107326375309186
# Iteration 37 condition value: 1.1027475843568932
# Iteration 38 condition value: 1.0983995370817194
# Iteration 39 condition value: 1.094267568934489
# Iteration 40 condition value: 1.0903382142933233
# Iteration 41 condition value: 1.0865990840506763
# Iteration 42 condition value: 1.0830387581506293
# Iteration 43 condition value: 1.0796466909651927
# Iteration 44 condition value: 1.0764131277350617
# Iteration 45 condition value: 1.0733290305773675
# Iteration 46 condition value: 1.0703860127920133
# Iteration 47 condition value: 1.067576280388328
# Iteration 48 condition value: 1.0648925799122286
# Iteration 49 condition value: 1.0623281517866707
# Iteration 50 condition value: 1.0598766884894792
# Iteration 51 condition value: 1.0575322969864884
# Iteration 52 condition value: 1.0552894649172333
# Iteration 53 condition value: 1.053143030097742
# Iteration 54 condition value: 1.0510881529622351
# Iteration 55 condition value: 1.0491202916144198
# Iteration 56 condition value: 1.0472351792009313
# Iteration 57 condition value: 1.0454288033553532
# Iteration 58 condition value: 1.0436973874922075
# Iteration 59 condition value: 1.0420373737569584
# Iteration 60 condition value: 1.0404454074611773
# Iteration 61 condition value: 1.0389183228520165
# Iteration 62 condition value: 1.0374531300825667
# Iteration 63 condition value: 1.036047003264818
# Iteration 64 condition value: 1.0346972695001904
# Iteration 65 condition value: 1.0334013987941935
# Iteration 66 condition value: 1.0321569947719231
# Iteration 67 condition value: 1.0309617861200404
# Iteration 68 condition value: 1.0298136186887232
# Iteration 69 condition value: 1.0287104481940321
# Iteration 70 condition value: 1.0276503334672318
# Iteration 71 condition value: 1.026631430203045
# Iteration 72 condition value: 1.0256519851636277
# Iteration 73 condition value: 1.0247103307992964
# Iteration 74 condition value: 1.0238048802508752
# Iteration 75 condition value: 1.0229341227018733
# Iteration 76 condition value: 1.022096619051753
# Iteration 77 condition value: 1.0212909978842333
# Iteration 78 condition value: 1.0205159517069924
# Iteration 79 condition value: 1.0197702334412921
# Iteration 80 condition value: 1.0190526531420026
# Iteration 81 condition value: 1.0183620749302345
# Iteration 82 condition value: 1.0176974141223736
# Iteration 83 condition value: 1.0170576345407172
# Iteration 84 condition value: 1.0164417459921953
# Iteration 85 condition value: 1.0158488019028067
# ...
# Iteration 24 condition value: 1.113022775257714
# Iteration 25 condition value: 1.1060284499088073
# Iteration 26 condition value: 1.0995464816798604
# Iteration 27 condition value: 1.0935296198704403
# Iteration 28 condition value: 1.0879361824601643
# Iteration 29 condition value: 1.082729243793605
# Iteration 30 condition value: 1.077875962734676
# Iteration 31 condition value: 1.0733470234426299
# Iteration 32 condition value: 1.0691161671054692
# Iteration 33 condition value: 1.065159797638157
# Iteration 34 condition value: 1.0614566479144234
# Iteration 35 condition value: 1.0579874958391253
# Iteration 36 condition value: 1.05473492169023
# Iteration 37 condition value: 1.0516830998164877
# Iteration 38 condition value: 1.048817619079859
# Iteration 39 condition value: 1.0461253274632711
# Iteration 40 condition value: 1.0435941970859663
# Iteration 41 condition value: 1.0412132065272373
# Iteration 42 condition value: 1.0389722378900526
# Iteration 43 condition value: 1.0368619864661077
# Iteration 44 condition value: 1.0348738812140768
# Iteration 45 condition value: 1.0330000145494431
# Iteration 46 condition value: 1.0312330801799783
# Iteration 47 condition value: 1.0295663179155277
# Iteration 48 condition value: 1.0279934645421847
# Iteration 49 condition value: 1.0265087099853316
# Iteration 50 condition value: 1.0251066580983559
# Iteration 51 condition value: 1.02378229150813
# Iteration 52 condition value: 1.0225309400276905
# Iteration 53 condition value: 1.0213482522136095
# Iteration 54 condition value: 1.0202301697023965
# Iteration 55 condition value: 1.0191729040085749
# Iteration 56 condition value: 1.0181729155083101
# Iteration 57 condition value: 1.0172268943677214
# Iteration 58 condition value: 1.0163317432052308
# Iteration 59 condition value: 1.015484561303335
# Iteration 60 condition value: 1.0146826302075929
# Iteration 61 condition value: 1.0139234005700202
# Iteration 62 condition value: 1.013204480110883
# Iteration 63 condition value: 1.0125236225874712
# Iteration 64 condition value: 1.0118787176711406
# Iteration 65 condition value: 1.0112677816450046
# Iteration 66 condition value: 1.0106889488443347
# Iteration 67 condition value: 1.0101404637702385
# Iteration 68 condition value: 1.0096206738146265
# Iteration 69 condition value: 1.0091280225410497
# Iteration 70 condition value: 1.0086610434717553
# Iteration 71 condition value: 1.0082183543364296
# Iteration 72 condition value: 1.0077986517425925
# Iteration 73 condition value: 1.0074007062316261
# Iteration 74 condition value: 1.0070233576879493
# Iteration 75 condition value: 1.006665511072029
# Iteration 76 condition value: 1.0063261324507082
# Iteration 77 condition value: 1.0060042453008482
# Iteration 78 condition value: 1.0056989270645191
# Iteration 79 condition value: 1.0054093059359757
# Iteration 80 condition value: 1.0051345578624453
# Iteration 81 condition value: 1.0048739037423704
# Iteration 82 condition value: 1.0046266068061867
# Iteration 83 condition value: 1.0043919701660293
# Iteration 84 condition value: 1.00416933452192
# Iteration 85 condition value: 1.0039580760130526
# Iteration 86 condition value: 1.0037576042037497
# Iteration 87 condition value: 1.003567360194519
# Iteration 88 condition value: 1.0033868148494325
# Iteration 89 condition value: 1.0032154671317495
# Iteration 90 condition value: 1.0030528425403564
# Iteration 91 condition value: 1.0028984916401742
# Iteration 92 condition value: 1.0027519886802263
# Iteration 93 condition value: 1.0026129302935307
# Iteration 94 condition value: 1.002480934273444
# Iteration 95 condition value: 1.0023556384214656
# Iteration 96 condition value: 1.0022366994618923
# Iteration 97 condition value: 1.0021237920190578
# Iteration 98 condition value: 1.002016607653183
# Iteration 99 condition value: 1.0019148539511642
# Iteration 100 condition value: 1.0018182536688776
# Iteration 0 condition value: 0.7054306044855622
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 1.9039583666798003
# Iteration 1 condition value: 1.7932076805178188
# Iteration 2 condition value: 1.7061284308756282
# Iteration 3 condition value: 1.635432900064674
# Iteration 4 condition value: 1.5766459340735075
# Iteration 5 condition value: 1.5268419106647864
# Iteration 6 condition value: 1.4840143339693472
# Iteration 7 condition value: 1.446733862937515
# Iteration 8 condition value: 1.4139504104298726
# Iteration 9 condition value: 1.3848725224178167
# Iteration 10 condition value: 1.3588906615247747
# Iteration 11 condition value: 1.3355266437872053
# Iteration 12 condition value: 1.3143992873498789
# Iteration 13 condition value: 1.295200457884447
# Iteration 14 condition value: 1.2776779799863265
# Iteration 15 condition value: 1.2616232005315842
# Iteration 16 condition value: 1.2468617758826057
# Iteration 17 condition value: 1.2332467385016714
# Iteration 18 condition value: 1.220653204374709
# Iteration 19 condition value: 1.20897428077423
# Iteration 20 condition value: 1.1981178650520512
# Iteration 21 condition value: 1.1880041136994999
# Iteration 22 condition value: 1.1785634217626793
# Iteration 23 condition value: 1.169734795199731
# Iteration 24 condition value: 1.1614645288936165
# Iteration 25 condition value: 1.1537051246830927
# Iteration 26 condition value: 1.1464143995288676
# Iteration 27 condition value: 1.1395547455307153
# Iteration 28 condition value: 1.1330925121436421
# Iteration 29 condition value: 1.1269974874306383
# Iteration 30 condition value: 1.121242460114184
# Iteration 31 condition value: 1.1158028479587125
# Iteration 32 condition value: 1.110656380926378
# Iteration 33 condition value: 1.1057828298121744
# Iteration 34 condition value: 1.1011637728382826
# Iteration 35 condition value: 1.0967823940870345
# Iteration 36 condition value: 1.0926233087632542
# Iteration 37 condition value: 1.088672411164731
# Iteration 38 condition value: 1.0849167419532542
# Iteration 39 condition value: 1.081344371895355
# Iteration 40 condition value: 1.0779442997104398
# Iteration 41 condition value: 1.074706362046495
# Iteration 42 condition value: 1.071621153917362
# Iteration 43 condition value: 1.0686799581941493
# Iteration 44 condition value: 1.0658746829573829
# Iteration 45 condition value: 1.0631978056943476
# Iteration 46 condition value: 1.0606423234744935
# Iteration 47 condition value: 1.0582017083600583
# Iteration 48 condition value: 1.0558698674135694
# Iteration 49 condition value: 1.0536411067520013
# Iteration 50 condition value: 1.0515100991719697
# Iteration 51 condition value: 1.0494718549336906
# Iteration 52 condition value: 1.0475216953453659
# Iteration 53 condition value: 1.045655228835759
# Iteration 54 condition value: 1.0438683292421973
# Iteration 55 condition value: 1.0421571160751666
# Iteration 56 condition value: 1.0405179365498776
# Iteration 57 condition value: 1.0389473492004222
# Iteration 58 condition value: 1.0374421089139876
# Iteration 59 condition value: 1.0359991532415482
# Iteration 60 condition value: 1.0346155898579628
# Iteration 61 condition value: 1.033288685058768
# Iteration 62 condition value: 1.0320158531935415
# Iteration 63 condition value: 1.0307946469466918
# Iteration 64 condition value: 1.0296227483861953
# Iteration 65 condition value: 1.0284979607092808
# Iteration 66 condition value: 1.0274182006215384
# Iteration 67 condition value: 1.0263814912925204
# Iteration 68 condition value: 1.0253859558367397
# Iteration 69 condition value: 1.024429811274119
# Iteration 70 condition value: 1.0235113629285488
# Iteration 71 condition value: 1.0226289992272513
# Iteration 72 condition value: 1.0217811868672992
# Iteration 73 condition value: 1.0209664663188451
# Iteration 74 condition value: 1.0201834476375076
# Iteration 75 condition value: 1.0194308065609428
# Iteration 76 condition value: 1.0187072808669269
# Iteration 77 condition value: 1.0180116669723474
# Iteration 78 condition value: 1.0173428167543686
# Iteration 79 condition value: 1.0166996345766854
# Iteration 80 condition value: 1.0160810745053073
# Iteration 81 condition value: 1.0154861376996491
# Iteration 82 condition value: 1.0149138699659432
# Iteration 83 condition value: 1.0143633594610788
# Iteration 84 condition value: 1.0138337345359891
# Iteration 85 condition value: 1.0133241617085973
# Iteration 86 condition value: 1.012833843757165
# Iteration 87 condition value: 1.012362017925624
# Iteration 88 condition value: 1.0119079542331544
# Iteration 89 condition value: 1.0114709538808861
# Iteration 90 condition value: 1.0110503477491564
# Iteration 91 condition value: 1.010645494979281
# Iteration 92 condition value: 1.010255781634248
# Iteration 93 condition value: 1.0098806194331729
# Iteration 94 condition value: 1.0095194445547573
# Iteration 95 condition value: 1.009171716505321
# Iteration 96 condition value: 1.008836917047335
# Iteration 97 condition value: 1.0085145491846623
# Iteration 98 condition value: 1.0082041362009861
# Iteration 99 condition value: 1.0079052207481796
# Iteration 100 condition value: 1.0076173639815675
# Iteration 0 condition value: 0.27965728151644853
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 0.58303189655167
# Breaking the loop due to the last value being within 1% of SCSS
# Iteration 0 condition value: 1.6953595258061898
# Iteration 1 condition value: 1.5992637435274686
# Iteration 2 condition value: 1.5247845776993783
# Iteration 3 condition value: 1.4650390443085333
# Iteration 4 condition value: 1.4158789756317507
# Iteration 5 condition value: 1.3746303127740034
# Iteration 6 condition value: 1.3394790858548487
# Iteration 7 condition value: 1.3091444645174137
# Iteration 8 condition value: 1.2826923034666122
# Iteration 9 condition value: 1.2594228423387055
# Iteration 10 condition value: 1.2387999832356866
# Iteration 11 condition value: 1.2204050655974672
# Iteration 12 condition value: 1.2039056862319377
# Iteration 13 condition value: 1.1890340911306643
# Iteration 14 condition value: 1.1755718447435606
# Iteration 15 condition value: 1.1633387265904596
# Iteration 16 condition value: 1.1521845416359962
# Iteration 17 condition value: 1.1419829808788582
# Iteration 18 condition value: 1.132626951349301
# Iteration 19 condition value: 1.1240249768188435
# Iteration 20 condition value: 1.1160983904600157
# Iteration 21 condition value: 1.1087791212810556
# Iteration 22 condition value: 1.1020079313029982
# Iteration 23 condition value: 1.0957329988088003
# Iteration 24 condition value: 1.0899087700898766
# Iteration 25 condition value: 1.0844950215218072
# Iteration 26 condition value: 1.0794560878795298
# Iteration 27 condition value: 1.074760223137724
# Iteration 28 condition value: 1.0703790676734752
# Iteration 29 condition value: 1.0662872015409781
# Iteration 30 condition value: 1.0624617678432549
# Iteration 31 condition value: 1.058882153552693
# Iteration 32 condition value: 1.0555297176948228
# Iteration 33 condition value: 1.052387558799255
# Iteration 34 condition value: 1.0494403150777645
# Iteration 35 condition value: 1.0466739920150023
# Iteration 36 condition value: 1.0440758130289076
# Iteration 37 condition value: 1.0416340896329526
# Iteration 38 condition value: 1.039338108154289
# Iteration 39 condition value: 1.0371780305637468
# Iteration 40 condition value: 1.0351448073807699
# Iteration 41 condition value: 1.0332301009483371
# Iteration 42 condition value: 1.0314262176448792
# Iteration 43 condition value: 1.0297260478240482
# Iteration 44 condition value: 1.0281230124582126
# Iteration 45 condition value: 1.0266110156151707
# Iteration 46 condition value: 1.0251844020255683
# Iteration 47 condition value: 1.0238379191056082
# Iteration 48 condition value: 1.022566682889587
# Iteration 49 condition value: 1.02136614740253
# Iteration 50 condition value: 1.0202320770673168
# Iteration 51 condition value: 1.0191605217949906
# Iteration 52 condition value: 1.018147794453216
# Iteration 53 condition value: 1.0171904504472993
# Iteration 54 condition value: 1.0162852691819635
# Iteration 55 condition value: 1.015429237201069
# Iteration 56 condition value: 1.0146195328274017
# Iteration 57 condition value: 1.0138535121462011
# Iteration 58 condition value: 1.0131286961946808
# Iteration 59 condition value: 1.0124427592359864
# Iteration 60 condition value: 1.0117935180100088
# Iteration 61 condition value: 1.0111789218657443
# Iteration 62 condition value: 1.0105970436905156
# Iteration 63 condition value: 1.010046071560725
# Iteration 64 condition value: 1.009524301046983
# Iteration 65 condition value: 1.0090301281136373
# Iteration 66 condition value: 1.0085620425590498
# Iteration 67 condition value: 1.0081186219485452
# Iteration 68 condition value: 1.007698525996878
# Iteration 69 condition value: 1.0073004913614203
# Iteration 70 condition value: 1.006923326811126
# Iteration 71 condition value: 1.0065659087397822
# Iteration 72 condition value: 1.006227176995065
# Iteration 73 condition value: 1.0059061309976747
# Iteration 74 condition value: 1.0056018261272273
# Iteration 75 condition value: 1.0053133703537402
# Iteration 76 condition value: 1.0050399210955079
# Iteration 77 condition value: 1.0047806822858756
# Iteration 78 condition value: 1.0045349016330007
# Iteration 79 condition value: 1.0043018680580724
# Iteration 80 condition value: 1.0040809092987333
# Iteration 81 condition value: 1.0038713896655844
# Iteration 82 condition value: 1.0036727079406655
# Iteration 83 condition value: 1.003484295407747
# Iteration 84 condition value: 1.0033056140050993
# Iteration 85 condition value: 1.0031361545921629
# Iteration 86 condition value: 1.0029754353222389
# Iteration 87 condition value: 1.0028230001139364
# Iteration 88 condition value: 1.002678417214693
# Iteration 89 condition value: 1.0025412778501914
# Iteration 90 condition value: 1.0024111949539745
# Iteration 91 condition value: 1.0022878019719907
# Iteration 92 condition value: 1.0021707517371945
# Iteration 93 condition value: 1.002059715409684
# Iteration 94 condition value: 1.0019543814781937
# Iteration 95 condition value: 1.001854454819056
# Iteration 96 condition value: 1.0017596558090274
# Iteration 97 condition value: 1.001669719488623
# Iteration 98 condition value: 1.0015843947728469
# Iteration 99 condition value: 1.0015034437064108
# Iteration 100 condition value: 1.0014266407607433
# Number of iterations completed for DataFrame P_10000.0_H2O_0.1_QFM1.2: 53
# Number of iterations completed for DataFrame P_10000.0_H2O_0.0_QFM1.2: 71
# Number of iterations completed for DataFrame P_10000.0_H2O_6.0_QFM1.2: 91
# Number of iterations completed for DataFrame P_10000.0_H2O_3.0_QFM1.2: 101
# Number of iterations completed for DataFrame P_10000.0_H2O_1.0_QFM1.2: 116
# Number of iterations completed for DataFrame P_8000.0_H2O_0.0_QFM1.2: 38
# Number of iterations completed for DataFrame P_8000.0_H2O_6.0_QFM1.2: 89
# Number of iterations completed for DataFrame P_8000.0_H2O_3.0_QFM1.2: 99
# Number of iterations completed for DataFrame P_8000.0_H2O_0.1_QFM1.2: 102
# Number of iterations completed for DataFrame P_8000.0_H2O_1.0_QFM1.2: 109
# Number of iterations completed for DataFrame P_4000.0_H2O_0.0_QFM1.2: 67
# Number of iterations completed for DataFrame P_4000.0_H2O_6.0_QFM1.2: 84
# Number of iterations completed for DataFrame P_4000.0_H2O_3.0_QFM1.2: 91
# Number of iterations completed for DataFrame P_4000.0_H2O_1.0_QFM1.2: 102
# Number of iterations completed for DataFrame P_4000.0_H2O_0.1_QFM1.2: 91
# Number of iterations completed for DataFrame P_2000.0_H2O_3.0_QFM1.2: 66
# Number of iterations completed for DataFrame P_2000.0_H2O_0.0_QFM1.2: 78
# Number of iterations completed for DataFrame P_2000.0_H2O_6.0_QFM1.2: 84
# Number of iterations completed for DataFrame P_2000.0_H2O_1.0_QFM1.2: 100
# Number of iterations completed for DataFrame P_2000.0_H2O_0.1_QFM1.2: 96
# Number of iterations completed for DataFrame P_1000.0_H2O_0.0_QFM1.2: 84
# Number of iterations completed for DataFrame P_1000.0_H2O_3.0_QFM1.2: 89
# Number of iterations completed for DataFrame P_1000.0_H2O_1.0_QFM1.2: 98
# Number of iterations completed for DataFrame P_1000.0_H2O_6.0_QFM1.2: 89
# Number of iterations completed for DataFrame P_500.0_H2O_0.0_QFM1.2: 86
# Number of iterations completed for DataFrame P_500.0_H2O_6.0_QFM1.2: 87
# Number of iterations completed for DataFrame P_500.0_H2O_3.0_QFM1.2: 87
# Number of iterations completed for DataFrame P_500.0_H2O_1.0_QFM1.2: 97

# %%
# check that all of our unique identifiers have been returned
result_dataframes.keys()
# Out:
# dict_keys(['P_10000.0_H2O_0.1_QFM1.2', 'P_10000.0_H2O_0.0_QFM1.2', 'P_10000.0_H2O_6.0_QFM1.2', 'P_10000.0_H2O_3.0_QFM1.2', 'P_10000.0_H2O_1.0_QFM1.2', 'P_8000.0_H2O_0.0_QFM1.2', 'P_8000.0_H2O_6.0_QFM1.2', 'P_8000.0_H2O_3.0_QFM1.2', 'P_8000.0_H2O_0.1_QFM1.2', 'P_8000.0_H2O_1.0_QFM1.2', 'P_4000.0_H2O_0.0_QFM1.2', 'P_4000.0_H2O_6.0_QFM1.2', 'P_4000.0_H2O_3.0_QFM1.2', 'P_4000.0_H2O_1.0_QFM1.2', 'P_4000.0_H2O_0.1_QFM1.2', 'P_2000.0_H2O_3.0_QFM1.2', 'P_2000.0_H2O_0.0_QFM1.2', 'P_2000.0_H2O_6.0_QFM1.2', 'P_2000.0_H2O_1.0_QFM1.2', 'P_2000.0_H2O_0.1_QFM1.2', 'P_1000.0_H2O_0.0_QFM1.2', 'P_1000.0_H2O_3.0_QFM1.2', 'P_1000.0_H2O_1.0_QFM1.2', 'P_1000.0_H2O_6.0_QFM1.2', 'P_500.0_H2O_0.0_QFM1.2', 'P_500.0_H2O_6.0_QFM1.2', 'P_500.0_H2O_3.0_QFM1.2', 'P_500.0_H2O_1.0_QFM1.2'])

# %% [markdown]
# ## Compile the contents of result_dataframes dict to one master frame

# %%
to_fill = pd.DataFrame() 

for key in result_dataframes:
 
    new = result_dataframes[key]
    
    to_fill = pd.concat([to_fill, new], ignore_index=True)

# %% [markdown]
# ## Calculating Cu/X ratios in the evolving melt

# %%
Cu_ratio = {'Ag':'new_Cmelt_Ag','Au':'new_Cmelt_Au','Se':'new_Cmelt_Se',
           'Re':'new_Cmelt_Re'}

                 
for key,val in Cu_ratio.items():
    # calculating Cu/X ratios of the melt after fluids and sulfide phase have formed
    # where X represents another chalcophile element
    to_fill['Cu/'+key+'_eqbm'] = to_fill['new_Cmelt_Cu'].div(to_fill[val])

# %%
to_fill['new_Msulf/Mfluid_Cu'] = to_fill['new_Msulf_Cu']/ to_fill['new_Mfluid_Cu']
to_fill['new_Msulf/Mfluid_S'] = to_fill['new_Msulf_S']/ to_fill['new_Mfluid_S']

# %% [markdown]
# ## Export completed iterated dataframe

# %%
# shape check - row should have same number as prior iteration
to_fill.shape
# Out:
# (2445, 600)

# %%
to_fill.unique.unique(), to_fill.shape

to_fill.to_csv('final_model_output.csv')

# %% [markdown]
# ## Dataframes for experimental data plotted and referred to in Fig S6 and S7

# %%
# Experimental data from Li and Audetat (2015) (LiAud2015) that is most relevant to our modelled FC paths (Fig S7a)

data = {
    'Ex.ID': ['C-1', 'C-7', 'C-11a', 'c12b', 'c13a'],
    'sulfide': ['DSL/SM',  'DMSS/SM', 'DSL/SM', 'MSS/SM', 'MSS/SM'],
    'DCu_sl': [790,  4600, 3800, 990, 13000],
    'DAg_sl': [450,  1600, 1100, 6, 30],
    'DAu_sl': [6100, 20600, 9000, 2000,10],
    'T_C': [1200,  1000, 1100, 900,1000],
    'FeOt_Liq': [8.5,   3.5, 3.5, 1, 3.5],
    'Comp': ['MORB',   'dac', 'dac', 'rhyo', 'dac']
}


liaud = pd.DataFrame(data)
print(liaud)
# Out:
#    Ex.ID  sulfide  DCu_sl  DAg_sl  DAu_sl   T_C  FeOt_Liq  Comp
# 0    C-1   DSL/SM     790     450    6100  1200       8.5  MORB
# 1    C-7  DMSS/SM    4600    1600   20600  1000       3.5   dac
# 2  C-11a   DSL/SM    3800    1100    9000  1100       3.5   dac
# 3   c12b   MSS/SM     990       6    2000   900       1.0  rhyo
# 4   c13a   MSS/SM   13000      30      10  1000       3.5   dac

# %%
# Experimental data from Kiseeva and Wood (2015) (KW2015):

data = {
    "Run No": ["Cu1-1", "Cu2-1", "Cu3-1", "Cu4-1", "Cu5-1", "Cu6-1", "Cu7-1", "Cu8-1", "Cu8-2", "Cu9-1", "Cu10-1", "Cu11-1", "Cu12-1", "KK12-2", "Ni3-1", "Ni5-2", "Ni6-2", "Ni7-1", "KK4-6", "KK4-7", "KK4-8", "KK4-9", "KK4-10", "KK15-6", "KK16-3", "Cu10-2", "Cu11-2", "Cu11-3", "Cu11-5"],
    "DCu_sl": [399, 398, 454, 569, 620, 519, 653, 608, 710, 724, 153, 729, 119, 61, 452, 316, 494, 267, 224, 200, 566, 278, 592, 88, 292, 150, 374, 343, 523],
    "DAg_sl": [364, 357, 395, 465, 507, 438, 507, 470, 537, 557, 186, 843, 167, 88, 660, 369, 436, 273, 234, 238, 633, 358, 649, 121, 388, 173, 467, 370, 616],
    "SiO2": [47.16, 45.44, 45.44, 49.39, 50.01, 48.84, 49.61, 49.34, 48.58, 49.28, 37.6, 45.83, 28.33, 29.54, 44.69, 51.94, 50.94, 46.82, 51.27, 48.72, 48.5, 49.16, 48.07, 38.54, 45.64, 38.5, 44.65, 44.9, 44.73],
    "FeO": [12.55, 13.8, 13.9, 9.24, 7.62, 8.82, 7.85, 8.39, 7.45, 7.2, 27.24, 3.21, 29.88, 37.88, 4.16, 2.33, 5.11, 11.68, 7.13, 8.36, 9.24, 8.74, 9.73, 27.02, 3.01, 26.4, 3.12, 2.83, 3.49],
    "MgO": [9.65, 9.06, 9.04, 10.11, 10.18, 10.4, 10.23, 10.09, 10.04, 10.21, 7.6, 14.92, 7.4, 7.16, 15.77, 10.81, 10.56, 9.64, 10.61, 10.6, 10.05, 10.16, 8.09, 7.98, 16.77, 7.8, 16.75,17.61,16.57]
}

KW2015_exp = pd.DataFrame(data)
KW2015_exp = KW2015_exp[KW2015_exp.FeO>3.5]

# %%
# All experimental data from Li and Audetat (2015) (LiAud2015):

data = {
    'RunNo': ['C-1', 'C-2', 'C-3', 'C-5', 'C-11a', 'C-11b', 'C-6', 'C-7', 'C-12a', 'C-12b', 'C-9a', 'C-9b', 'C-10a', 'C-10b', 'C-13a', 'C-13b'],
    'T_C': [1200, 1200, 1200, 1200, 1100, 1100, 1000, 1000, 900, 900, 1000, 1000, 1000, 1000, 1000, 1000],
    'FeOt_Liq': [8.5, 4.5, 3.5, 1, 3.5, 1, 1, 3.5, 3.5, 1, 3.5, 1, 3.5, 1, 3.5, 1],
    'Sulfide': ['DSL/SM', 'DSL/SM', 'DSL/SM', 'DSL/SM', 'DSL/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM', 'DMSS/SM'],
    'DCu_sl': [790, 1600, 1700, 3100, 3800, 14600, 3400, 740, 5800, 42000, 500, 660, 720, 450, 610, 1100],
    'DAg_sl': [450, 740, 820, 1100, 1100, 500, 99, 29, 56, 440, 13, 10, 22, 12, 8, 11],
    'DAu_sl': [6100, 2000, 10500, 28700, 9000, 350, 510, 410, 380, 2000, 70, 89, 28, 180, 10, 43]
}

liaud_all = pd.DataFrame(data)

# %%
# Experimental data from Kiseeva and Wood (2013) (KW2013):

data = {
    'Run No.': ['KK3-1', 'KK3-2', 'KK4-1', 'KK4-3', 'KK5-1', 'KK5-2', 'KK6-1', 'KK6-3', 'KK7-1', 'KK7-2', 'KK8-1', 'KK8-2', 'KK12-1', 'KK15-1', 'KK15-2', 'KK15-4', 'KK15-5', 'KK16-1', 'KK16-2'],
    'DCu_sl': [542.8, 461, 460.6, 549.6, 471.8, 445.3, 433, 487.3, 496.9, 675.1, 565.3, 636.1, 38.2, 146.4, 162.4, 120.5, 179.1, 396.2, 554.5],
    'DAg_sl': [581.2, 588.6, 552.5, 775.3, 592.7, 574.8, 593.9, 627.1, 668.3, 954.9, 909.6, 857.3, 53.9, 194.5, 266.9, 171.5, 261.9, 569.1, 909],
    'n': [12, 23, 12, 20, 22, 12, 25, 25, 12, 27, 23, 24, 16, 28, 18, 49, 42, 41, 32],
    'SiO2': [50.55, 48.23, 50.3, 48.27, 49.34, 46.52, 47.94, 48.85, 48.05, 46.68, 48.75, 50.7, 30.99, 38.01, 35.68, 37.48, 37.19, 44.75, 45.1],
    'TiO2': [0.82, 0.7, 0.73, 0.73, 0.72, 0.61, 0.7, 0.68, 0.68, 0.64, 0.6, 0.66, 0.47, 0.61, 0.55, 0.58, 0.58, 0, 0],
    'Al2O3': [15.38, 12.75, 13.38, 13.82, 13.52, 15.3, 13.4, 12.88, 12.96, 12.18, 10.03, 12.54, 9.69, 11.99, 10.64, 11.36, 11.25, 17.36, 17.3],
    'FeO': [7.5, 7.98, 7.42, 7.4, 7.15, 6.67, 7.69, 7.73, 8.08, 7.78, 3.4, 3.27, 40.06, 26.07, 25.79, 27.8, 28.78, 3.18, 2.9],
    'MgO': [10.44,16.29,15.56,14.25,15.72,12.79,15.71,17.15,15.89,17.22,22.94,19.75,8.87,7.97,8.36,8.12,8.04,16.99,16.25 ]
}

KW2013_exp = pd.DataFrame(data)

# %%
# all experimental data
liaud_all['KdCu/KdAg'] = liaud_all['DCu_sl'] / liaud_all['DAg_sl']
sulfide_values = liaud_all['Sulfide'].unique()

for sulfide_value in sulfide_values:
    subset_df = liaud_all[liaud_all['Sulfide'] == sulfide_value]
    color = 'yellow' if sulfide_value == 'DSL/SM' else 'pink'  
    plt.scatter(subset_df['FeOt_Liq'], subset_df['KdCu/KdAg'], label=f'other LiAud15 Kd: {sulfide_value}', color=color, alpha=0.3, s=50, edgecolor='k')

# the most relevant to us
sulfide_values = liaud['sulfide'].unique()
liaud['KdCu/KdAg'] = liaud['DCu_sl'] / liaud['DAg_sl']

for sulfide_value in sulfide_values:
    subset_df = liaud[liaud['sulfide'] == sulfide_value]
    color = 'yellow' if sulfide_value == 'DSL/SM' else 'pink'  
    plt.scatter(subset_df['FeOt_Liq'], subset_df['KdCu/KdAg'], label=f'relevant LiAud15 Kd: {sulfide_value}', color=color, alpha=0.7, s=200, edgecolor='k')

    
# Kiseeva    
KW2013_exp['KdCu/KdAg'] = KW2013_exp['DCu_sl'] /  KW2013_exp['DAg_sl'] 
plt.scatter(KW2013_exp['FeO'],KW2013_exp['KdCu/KdAg'], label='KW2013 Kd:DSL/SM', color='yellow',marker='X',alpha=0.7, s=200, edgecolor='k')
    

# Overlay my combined Kd dataset:
for v in to_fill.newcolumn.unique():
    df_v = to_fill[to_fill.newcolumn == v]
    for p in [4000, 2000, 1000,500]:
        df_vp = df_v[df_v.pressure_bar == p]
        x = df_vp['FeOt_Liq']
        y = df_vp['DCu_sulfsil'] / df_vp['DAg_sulfsil']
        
        plt.plot(x, y, color=om_dict[v],linestyle=pdict[p], alpha=0.7, linewidth=2,zorder=2)
        
    
    
# Add labels and legend
plt.xlim(0,13)
#plt.ylim(0.68,0.8)
plt.yscale('log')
plt.xlabel('FeOt wt%', fontsize=20, weight='bold')
plt.ylabel('KdCu / KdAg', fontsize=20, weight='bold')
plt.grid(color='grey', which='both', alpha=0.1, zorder=0)
plt.legend(fontsize=10)

plt.show()

# %%
from matplotlib.cm import viridis, cividis
from cmcrameri import cm
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

om_dict = {'H2O_0.1_QFM1.2':'#b3ecff','H2O_1.0_QFM1.2': '#33bbff', 'H2O_3.0_QFM1.2':'#0086b3', 'H2O_6.0_QFM1.2':'#001a33','H2O_0.0_QFM1.2':'red'}

pressure = to_fill['pressure_bar'].unique()
lines = ['solid','solid','solid', 'dashdot', 'dashed', 'dotted']
#lines = ['solid', 'dashdot', 'dashed', 'dotted']
pdict = dict(zip(pressure, lines))

plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 16

fig, ax = plt.subplots(1, 2, figsize=(15, 6))


for v in to_fill.newcolumn.unique():
    df_v = to_fill[to_fill.newcolumn == v]
    for p in [4000, 2000, 1000,500]:
        df_vp = df_v[df_v.pressure_bar == p]
        y = df_vp['DCu_sl']
        x = df_vp['MgO_Liq']
        
        ax[0].plot(x, y, color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)
        ax[1].plot(x, df_vp['DCu_sulfsil'],color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)
        
        
ax = ax.flatten()
for i in range(2):

    ax[i].tick_params(axis='both', which='both',top=True,right=True, labelsize=12, direction='in')
    ax[i].set_xlim(1.1,12.1)
    ax[i].grid(color='grey',which='both', alpha=0.1, zorder=0)
    ax[i].tick_params(axis='both', which='both', labelsize=15, direction='in', top=True,right=True)
    ax[i].set_xlabel('MgO wt%', fontsize=20,weight='bold')
    if i == 0:
        ax[i].set_ylabel('DCu_sl KW2013', fontsize=20, weight='bold')
        ax[i].set_ylim(0,4000)
        
    if i == 1:
        ax[i].set_ylabel('DCu SULF/SIL COMBINED', fontsize=20, weight='bold')
        ax[i].set_ylim(0,4000)

# %%
from matplotlib.cm import viridis, cividis
from cmcrameri import cm
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

om_dict = {'H2O_0.1_QFM1.2':'#b3ecff','H2O_1.0_QFM1.2': '#33bbff', 'H2O_3.0_QFM1.2':'#0086b3', 'H2O_6.0_QFM1.2':'#001a33','H2O_0.0_QFM1.2':'red'}

pressure = to_fill['pressure_bar'].unique()
lines = ['solid','solid','solid', 'dashdot', 'dashed', 'dotted']
#lines = ['solid', 'dashdot', 'dashed', 'dotted']
pdict = dict(zip(pressure, lines))

plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 16

fig, ax = plt.subplots(1, 2, figsize=(15, 7))

for v in to_fill.newcolumn.unique():
    df_v = to_fill[to_fill.newcolumn == v]
    for p in [4000, 2000, 1000,500]:
        df_vp = df_v[df_v.pressure_bar == p]
        y = df_vp['new_Csulf_Cu']
        x = df_vp['FeOt_Liq']
        
        ax[0].plot(x, y, color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)
        ax[1].plot(x, df_vp['DCu_sl'],color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)

ax = ax.flatten()
for i in range(2):

    ax[i].tick_params(axis='both', which='both',top=True,right=True, labelsize=12, direction='in')
    ax[i].set_xlim(1.1,12.1)
    ax[i].grid(color='grey',which='both', alpha=0.1, zorder=0)
    ax[i].tick_params(axis='both', which='both', labelsize=15, direction='in', top=True,right=True)
    ax[i].set_xlabel('FeOt wt%', fontsize=20,weight='bold')
    
    if i == 0:
        ax[i].set_ylabel('Cu in sulfide wt%', fontsize=20, weight='bold')
        ax[i].set_ylim(-1,40)
        
    if i == 1:
        ax[i].set_ylabel('Modelled D$^\mathrm{Cu}_\mathrm{SL}$', fontsize=20, weight='bold')
        ax[i].set_ylim(-10,4000)
        
# legend
from matplotlib.lines import Line2D
items = list(pdict.values())
color = list(om_dict.values())
line_pressure = [Line2D([0], [0], color=color[3], lw=3),
                Line2D([0], [0], color=color[2], lw=3),
                Line2D([0], [0], color=color[1], lw=3),
                Line2D([0], [0], color=color[0],lw=3),
                 Line2D([0], [0], color=color[4],lw=3),
                 
               Line2D([0], [0], color='k',linestyle=items[2], lw=1.5),
                Line2D([0], [0], color='k',linestyle=items[3], lw=1.5),
                 Line2D([0], [0], color='k',linestyle=items[4], lw=1.5),
                 Line2D([0], [0], color='k',linestyle=items[5], lw=1.5),] 
ax[1].legend(line_pressure, [ '$H_{2}O$ 6 wt%','$H_{2}O$ 3 wt%', '$H_{2}O$ 1 wt%', '$H_{2}O$ 0.1 wt%','$H_{2}O$ 0.0 wt%',
    '400 MPa','200 MPa',  '100 MPa','50 MPa',], fontsize = 13, 
             frameon=True,edgecolor='k', borderpad=0.8, ncol=1, loc='right', framealpha=1)

import matplotlib.patches as mpatches        
labels = ['a.' , 'b.', ]
for i, label in enumerate(labels):
    ax[i].text(0.9, 0.9, f'{label}', fontsize=22, color='black', zorder=5, transform=ax[i].transAxes)
    
plt.tight_layout()

# %%
om_dict = {'H2O_0.1_QFM1.2':'#b3ecff','H2O_1.0_QFM1.2': '#33bbff', 'H2O_3.0_QFM1.2':'#0086b3', 'H2O_6.0_QFM1.2':'#001a33','H2O_0.0_QFM1.2':'red'}

pressure = to_fill['pressure_bar'].unique()
lines = ['solid','solid','solid', 'dashdot', 'dashed', 'dotted']
#lines = ['solid', 'dashdot', 'dashed', 'dotted']
pdict = dict(zip(pressure, lines))

plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 16

fig, ax = plt.subplots(1, 2, figsize=(15, 7))

for v in to_fill.newcolumn.unique():
    df_v = to_fill[to_fill.newcolumn == v]
    for p in [4000, 2000, 1000,500]:
        df_vp = df_v[df_v.pressure_bar == p]
        y = df_vp['new_Csulf_Cu']
        x = df_vp['FeOt_Liq']
        
        ax[0].plot(x, y, color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)
        ax[1].plot(x, df_vp['DCu_sulfsil'],color=om_dict[v], label=p, linestyle=pdict[p], alpha=1, linewidth=2)

ax = ax.flatten()
for i in range(2):

    ax[i].tick_params(axis='both', which='both',top=True,right=True, labelsize=12, direction='in')
    ax[i].set_xlim(0,13)
    ax[i].grid(color='grey',which='both', alpha=0.1, zorder=0)
    ax[i].tick_params(axis='both', which='both', labelsize=15, direction='in', top=True,right=True)
    ax[i].set_xlabel('FeOt wt%', fontsize=20,weight='bold')
    
    if i == 0:
        ax[i].set_ylabel('Cu in sulfide wt%', fontsize=20, weight='bold')
        ax[i].set_ylim(-1,40)
        
    if i == 1:
        ax[i].set_ylabel('Modelled D$^\mathrm{Cu}_\mathrm{SL}$ and D$^\mathrm{Cu}_\mathrm{MSS}$', fontsize=20, weight='bold')
        ax[i].set_ylim(-10,4000)
        
# legend
from matplotlib.lines import Line2D
items = list(pdict.values())
color = list(om_dict.values())
line_pressure = [Line2D([0], [0], color=color[3], lw=3),
                Line2D([0], [0], color=color[2], lw=3),
                Line2D([0], [0], color=color[1], lw=3),
                Line2D([0], [0], color=color[0],lw=3),
                 Line2D([0], [0], color=color[4],lw=3),
                 
               Line2D([0], [0], color='k',linestyle=items[2], lw=1.5),
                Line2D([0], [0], color='k',linestyle=items[3], lw=1.5),
                 Line2D([0], [0], color='k',linestyle=items[4], lw=1.5),
                 Line2D([0], [0], color='k',linestyle=items[5], lw=1.5),] 
ax[1].legend(line_pressure, [ '$H_{2}O$ 6 wt%','$H_{2}O$ 3 wt%', '$H_{2}O$ 1 wt%', '$H_{2}O$ 0.1 wt%','$H_{2}O$ 0.0 wt%',
    '400 MPa','200 MPa',  '100 MPa','50 MPa',], fontsize = 13, 
             frameon=True,edgecolor='k', borderpad=0.8, ncol=1, loc='right', framealpha=1)

import matplotlib.patches as mpatches        
labels = ['c.' , 'd.', ]
for i, label in enumerate(labels):
    ax[i].text(0.9, 0.9, f'{label}', fontsize=22, color='black', zorder=5, transform=ax[i].transAxes)
    
plt.tight_layout()
